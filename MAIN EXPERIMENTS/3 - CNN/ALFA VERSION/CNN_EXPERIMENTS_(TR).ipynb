# %% [markdown]
# # Ajustes iniciales

# %% [markdown]
# ## Conexión a drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd ./drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks'

# %% [markdown]
# ## Importar los módulos *_utils

# %%
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/')
from my_utils import dataset_utils
from my_utils import eval_utils
from my_utils import nn_utils
from my_utils import results_utils

# %%
import pickle

# %% [markdown]
# # Funciones locales

# %% [markdown]
# ## Prototipo de modelo

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout,SpatialDropout1D
from tensorflow import keras
from tensorflow.keras import layers

def convolutionalNetModel(task, params, optimizer, verbose = False):
  """
  Defines and compiles a new Keras model for a Convolutional Neural Network

  """

  SEQ_LENGTH = 55
  VEC_EMBEDDINGS_DIM = 300

  kernel_size_1, kernel_size_2, kernel_size_3 = params['kernels_combos']
  cnn_activation = params['conv_layers_activation']
  n_filters = params['n_filters']
  DL_1, DL_2 = params['dense_layers_sizes']
  spatial_dropout = params['spatial_dropout']
  dense_dropout = params['dense_dropout']

  embedding_sequences_input = keras.Input(name='INPUT', shape=(SEQ_LENGTH, VEC_EMBEDDINGS_DIM), dtype="float64")

  cnn_1 = layers.Conv1D(n_filters, kernel_size_1, activation=cnn_activation, name = 'CNN1')(embedding_sequences_input)
  cnn_1 = layers.SpatialDropout1D(spatial_dropout, name = 'SPATIAL_DROPOUT_1')(cnn_1)
  
  cnn_2 = layers.Conv1D(n_filters, kernel_size_2, activation=cnn_activation, name = 'CNN2')(embedding_sequences_input)
  cnn_2 = layers.SpatialDropout1D(spatial_dropout, name = 'SPATIAL_DROPOUT_2')(cnn_2)
  
  cnn_3 = layers.Conv1D(n_filters, kernel_size_3, activation=cnn_activation, name = 'CNN3')(embedding_sequences_input)
  cnn_3 = layers.SpatialDropout1D(spatial_dropout, name = 'SPATIAL_DROPOUT_3')(cnn_3)

  if params['pooling_method'] == 'max':
    cnn_1 = layers.GlobalMaxPooling1D(name = 'MAX_POOL_1')(cnn_1)
    cnn_2 = layers.GlobalMaxPooling1D(name = 'MAX_POOL_2')(cnn_2)
    cnn_3 = layers.GlobalMaxPooling1D(name = 'MAX_POOL_3')(cnn_3)
  elif params['pooling_method'] == 'average':
    cnn_1 = layers.GlobalAveragePooling1D(name = 'MAX_POOL_1')(cnn_1)
    cnn_2 = layers.GlobalAveragePooling1D(name = 'MAX_POOL_2')(cnn_2)
    cnn_3 = layers.GlobalAveragePooling1D(name = 'MAX_POOL_3')(cnn_3)

  fcnn = layers.Concatenate(axis=1, name = 'CONCATENATE')([cnn_1, cnn_2, cnn_3])
  fcnn = layers.Dense(DL_1, activation="relu", name = 'DL_1')(fcnn)
  fcnn = layers.Dropout(dense_dropout, name = 'DENSE_DROP_1')(fcnn)
  fcnn = layers.Dense(DL_2, activation="relu", name = 'DL_2')(fcnn)
  fcnn = layers.Dropout(dense_dropout, name = 'DENSE_DROP_2')(fcnn)

  if task in ['HS', 'TR', 'AG']:
    preds = layers.Dense(1, activation="sigmoid", name = 'PREDICTOR')(fcnn)
    model = keras.Model(embedding_sequences_input, preds)

    model.compile(loss="binary_crossentropy", optimizer=optimizer, metrics=["acc"])

  elif task == 'HTA':
    preds = layers.Dense(5, activation="softmax", name = 'PREDICTOR')(fcnn)
    preds = reshape = layers.Reshape(target_shape=(5,))(preds)

    model = keras.Model(embedding_sequences_input, preds)
    model.compile(loss="categorical_crossentropy", optimizer=optimizer, metrics=["acc"])

  if verbose:
    model.summary()

  return model

# %% [markdown]
# # Combinaciones de tamaños de kernel

# %% [markdown]
# ## Dataset

# %%
X_train, Y_train = dataset_utils.loadEncodedTrainData(embedding_type='FT3',
                                                 encoding_format='EMB-SEQ',
                                                 labels_to_return=['TR'],
                                                 n_folds=7
                                                 )
# Out:
# FastText 3 - Spanish Unannotated Corpora
# Encoding Format: EMB-SEQ
#
# Process complete
# 5000 train instances retrieved
#
# encodings_dim = (55, 300)

# %% [markdown]
# ## Espacio de búsqueda

# %% [markdown]
# **Parámetros de la arquitectura**

# %%
from itertools import product

from itertools import combinations
from itertools import product

candidate_kernels = [1,2,3,4,5]
kernels_combos = list(combinations(candidate_kernels, 3))

dense_layers_sizes = [(300,100),
                      (200,100)]                    

arch_params = {'kernels_combos':kernels_combos,
              'dense_layers_sizes':dense_layers_sizes,
              'n_filters':[50,100,150],
              'conv_layers_activation':['tanh'],
              'pooling_method':['max'],
              'spatial_dropout':[0.5],
              'dense_dropout':[0.5]} 

arch_params_keys = arch_params.keys()

arch_params_combos = list(product( *arch_params.values() ))          

#arch_params_combos = [params_combo for params_combo in arch_params_combos if params_combo[-2]>=params_combo[-1]]
print('{} arch_params_combos.'.format(len(arch_params_combos)))
# Out:
# 60 arch_params_combos.

# %% [markdown]
# **Parámetros de la arquitectura**

# %%
trainig_params_dict = {'optimizer':['adam-1e-3', 'rmsprop-1e-3'],
                       'batch_size':[512],
                       'max_epochs':[75]}

training_params_keys = trainig_params_dict.keys()
trainig_params_combos = list(product( *trainig_params_dict.values() ))

print('\n{} trainig_params_combos.'.format(len(trainig_params_combos)))
# Out:
# 2 trainig_params_combos.

# %%
search_space = list(product(arch_params_combos, trainig_params_combos))

print('\n{} params combinations in the search_space.'.format(len(search_space)))
# Out:
# 120 params combinations in the search_space.

# %% [markdown]
# ## Escaneo

# %%
results_df = nn_utils.spaceScanner(X_train, Y_train,
                          'HS',
                          convolutionalNetModel, 
                          search_space,
                          arch_params_keys,
                          training_params_keys,
                          fraction2eval=1,
                          n_folds=7,
                          fitting_attemps=1,
                          stop_threshold=1,
                          partial_CV=True,
                          backup_file='./Results/CNN/HS_kernels_experiments.df',
                          backup_freq=5,
                          save_history_files=True,
                          save_models_as_json=False)

# %% [markdown]
# ## Resultados

# %%
import pickle
from pandas import DataFrame

with open('./Results/CNN/HS_kernels_experiments.df', 'rb') as file_handler:
  search_results = pickle.load(file_handler)

search_results.shape
# Out:
# (120, 19)

# %%
from itertools import combinations
from itertools import product

candidate_kernels = [1,2,3,4,5]
kernels_combos = list(combinations(candidate_kernels, 3))

params_dict = {'kernels_combos':kernels_combos}

# %%
results_utils.plotResultsByParameter1(search_results, 
                       params_dict, 
                       params2plot=['kernels_combos'],
                       metric='val_acc_A')

results_utils.plotResultsByParameter1(search_results, 
                       params_dict, 
                       params2plot=['kernels_combos'],
                       metric='val_acc_B')

# %%
params_dict = {'n_filters':[50,100,150]}

results_utils.plotResultsByParameter1(search_results, 
                       params_dict, 
                       params2plot=['n_filters'],
                       metric='val_acc_A')

results_utils.plotResultsByParameter1(search_results, 
                       params_dict, 
                       params2plot=['n_filters'],
                       metric='val_acc_B')

# %% [markdown]
# ### Resumen de los resultados
#
# * Mejores combinaciones de kernels sizes: (1,2,3), (2,3,4)
# * lstm_units: [100,200]

# %% [markdown]
# # Experimentos con optimizadores

# %% [markdown]
# ## Dataset

# %%
X_train, Y_train = dataset_utils.loadEncodedTrainData(embedding_type='FT3',
                                                 encoding_format='EMB-SEQ',
                                                 labels_to_return=['HS'],
                                                 n_folds=7
                                                 )
# Out:
# FastText 3 - Spanish Unannotated Corpora
# Encoding Format: EMB-SEQ
#
# Process complete
# 5000 train instances retrieved
#
# encodings_dim = (55, 300)

# %% [markdown]
# ## Espacio de búsqueda

# %% [markdown]
# **Parámetros de la arquitectura**

# %%
from itertools import product

from itertools import combinations
from itertools import product

dense_layers_sizes = [(300,100),
                      (200,100)]                    

arch_params = {'kernels_combos':[(1,2,3),(2,3,4)],
              'dense_layers_sizes':dense_layers_sizes,
              'n_filters':[100,150,200],
              'conv_layers_activation':['tanh'],
              'pooling_method':['max'],
              'spatial_dropout':[0.5],
              'dense_dropout':[0.5]} 

arch_params_keys = arch_params.keys()

arch_params_combos = list(product( *arch_params.values() ))          

#arch_params_combos = [params_combo for params_combo in arch_params_combos if params_combo[-2]>=params_combo[-1]]
print('{} arch_params_combos.'.format(len(arch_params_combos)))
# Out:
# 12 arch_params_combos.

# %% [markdown]
# **Parámetros de la arquitectura**

# %%
trainig_params_dict = {'optimizer':['adam-1e-3', 'adam-5e-4', 'adam-1e-4', 'rmsprop-1e-3', 'rmsprop-5e-4', 'rmsprop-1e-4'],
                       'batch_size':[512],
                       'max_epochs':[75]}
                        

training_params_keys = trainig_params_dict.keys()
trainig_params_combos = list(product( *trainig_params_dict.values() ))

print('\n{} trainig_params_combos.'.format(len(trainig_params_combos)))
# Out:
# 6 trainig_params_combos.

# %%
search_space = list(product(arch_params_combos, trainig_params_combos))

print('\n{} params combinations in the search_space.'.format(len(search_space)))
# Out:
# 72 params combinations in the search_space.

# %% [markdown]
# ## Escaneo

# %%
results_df = nn_utils.spaceScanner(X_train, Y_train,
                          'HS',
                          convolutionalNetModel, 
                          search_space,
                          arch_params_keys,
                          training_params_keys,
                          fraction2eval=1,
                          n_folds=7,
                          fitting_attemps=1,
                          stop_threshold=1,
                          partial_CV=True,
                          backup_file='./Results/CNN/HS_experiments_1.df',
                          backup_freq=5,
                          save_history_files=True,
                          save_models_as_json=False)
# Out:
# BackupFile: ./Results/CNN/HTA_experiments_1_batch_1.df
# SCANNING SEARCH SPACE
#
# 36 configurations will be evaluated.
# 1  - conf_ID: xbdqfQrF   ****  --  train_acc_A = 0.813,  val_acc_A = 0.742    --  train_acc_B = 0.721,  val_acc_B = 0.757
# 2  - conf_ID: VjevGVyM

# %% [markdown]
# ## Resultados

# %%
import pickle
from pandas import DataFrame

with open('./Results/CNN/HS_experiments_1.df', 'rb') as file_handler:
  search_results = pickle.load(file_handler)

search_results.shape
# Out:
# (72, 18)

# %%
search_results.sort_values(by='val_acc_A', ascending=False).head()
# Out:
#      conf_ID kernels_combos  ... train_acc_B  val_acc_B
# 8   GVXLmSCp      (1, 2, 3)  ...    0.847051   0.817996
# 26  SKvpwzRg      (1, 2, 3)  ...    0.819923   0.817293
# 25  NGKrIoqO      (1, 2, 3)  ...    0.846171   0.818692
# 31  KFCAehWG      (1, 2, 3)  ...    0.833049   0.814143
# 51  WEaABmFT      (2, 3, 4)  ...    0.800678   0.813445
#
# [5 rows x 18 columns]

# %%
search_results.sort_values(by='val_acc_B', ascending=False).head()
# Out:
#      conf_ID kernels_combos  ... train_acc_B  val_acc_B
# 25  NGKrIoqO      (1, 2, 3)  ...    0.846171   0.818692
# 8   GVXLmSCp      (1, 2, 3)  ...    0.847051   0.817996
# 26  SKvpwzRg      (1, 2, 3)  ...    0.819923   0.817293
# 69  oPXXqxfE      (2, 3, 4)  ...    0.832291   0.817292
# 50  ljPktBlA      (2, 3, 4)  ...    0.881583   0.815545
#
# [5 rows x 18 columns]

# %%
params_dict = {'optimizer':['adam-1e-3', 'adam-5e-4', 'adam-1e-4', 
                            'rmsprop-1e-3', 'rmsprop-5e-4', 'rmsprop-1e-4']}

# %%
results_utils.plotResultsByParameter1(search_results, 
                       params_dict, 
                       params2plot=['optimizer'],
                       metric='val_acc_A')

results_utils.plotResultsByParameter1(search_results, 
                       params_dict, 
                       params2plot=['optimizer'],
                       metric='val_acc_B')

# %%
params_dict = {'n_filters':[100,150,200]}

results_utils.plotResultsByParameter1(search_results, 
                       params_dict, 
                       params2plot=['n_filters'],
                       metric='val_acc_A')

results_utils.plotResultsByParameter1(search_results, 
                       params_dict, 
                       params2plot=['n_filters'],
                       metric='val_acc_B')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ### Resumen de los resultados
#
# * Mejores combinaciones de kernels sizes: (1,2,3), (2,3,4)
# * lstm_units: [150,200]
# * Optimizador: 'adam-1e-4', 'rmsprop-1e-3'

# %% [markdown]
# # Experimentos con el tamaño de las capas densas

# %% [markdown]
# ## Dataset

# %%
X_train, Y_train = dataset_utils.loadEncodedTrainData(embedding_type='FT3',
                                                 encoding_format='EMB-SEQ',
                                                 labels_to_return=['TR'],
                                                 n_folds=7
                                                 )
# Out:
# FastText 3 - Spanish Unannotated Corpora
# Encoding Format: EMB-SEQ
#
# Process complete
# 5000 train instances retrieved
#
# encodings_dim = (55, 300)

# %% [markdown]
# ## Espacio de búsqueda

# %% [markdown]
# **Parámetros de la arquitectura**

# %%
from itertools import product

from itertools import combinations
from itertools import product

dense_layers_sizes = [(400,100),
                      (400,75), 
                      (300,100),
                      (300,75),
                      (200,100),
                      (200,75)]                    

arch_params = {'kernels_combos':[(1,2,3),(2,3,4)],
              'dense_layers_sizes':dense_layers_sizes,
              'n_filters':[150,200],
              'conv_layers_activation':['tanh'],
              'pooling_method':['max'],
              'spatial_dropout':[0.5],
              'dense_dropout':[0.5]} 

arch_params_keys = arch_params.keys()

arch_params_combos = list(product( *arch_params.values() ))          

#arch_params_combos = [params_combo for params_combo in arch_params_combos if params_combo[-2]>=params_combo[-1]]
print('{} arch_params_combos.'.format(len(arch_params_combos)))
# Out:
# 24 arch_params_combos.

# %% [markdown]
# **Parámetros de la arquitectura**

# %%
trainig_params_dict = {'optimizer':['adam-1e-4', 'rmsprop-1e-3'],
                       'batch_size':[512],
                       'max_epochs':[75]}
                        

training_params_keys = trainig_params_dict.keys()
trainig_params_combos = list(product( *trainig_params_dict.values() ))

print('\n{} trainig_params_combos.'.format(len(trainig_params_combos)))
# Out:
# 2 trainig_params_combos.

# %%
search_space = list(product(arch_params_combos, trainig_params_combos))

print('\n{} params combinations in the search_space.'.format(len(search_space)))
# Out:
# 48 params combinations in the search_space.

# %% [markdown]
# ## Escaneo

# %%
results_df = nn_utils.spaceScanner(X_train, Y_train,
                          'TR',
                          convolutionalNetModel, 
                          search_space,
                          arch_params_keys,
                          training_params_keys,
                          fraction2eval=1,
                          n_folds=7,
                          fitting_attemps=1,
                          stop_threshold=1,
                          partial_CV=True,
                          backup_file='./Results/CNN/TR/experiments_2.df',
                          backup_freq=5,
                          save_history_files=True,
                          save_models_as_json=False)
# Out:
# BackupFile: ./Results/CNN/TR/experiments_2.df
# SCANNING SEARCH SPACE
#
# 48 configurations will be evaluated.
# 1  - conf_ID: gwlvFiVp   ****  --  train_acc_1 = 0.891,  val_acc_1 = 0.888    --  train_acc_2 = 0.872,  val_acc_2 = 0.9
# 2  - conf_ID: ADTVbcEi   ****  --  train_acc_1 = 0.84,   val_acc_1 = 0.892    --  train_acc_2 = 0.85,   val_acc_2 = 0.902
# 3  - conf_ID: fUPvFphQ   ****  --  train_acc_1 = 0.87,   val_acc_1 = 0.897    --  train_acc_2 = 0.894,  val_acc_2 = 0.901
# 4  - conf_ID: MAVsVStF   ****  --  train_acc_1 = 0.858,  val_acc_1 = 0.9      --  train_acc_2 = 0.859,  val_acc_2 = 0.901
# 5  - conf_ID: FlXoHJkz   ****  --  train_acc_1 = 0.866,  val_acc_1 = 0.894    --  train_acc_2 = 0.876,  val_acc_2 = 0.897
# 6  - conf_ID: YteYUpSe   ****  --  train_acc_1 = 0.87,   val_acc_1 = 0.889    --  train_acc_2 = 0.843,  val_acc_2 = 0.895
# 7  - conf_ID: ZdKahMjW   ****  --  train_acc_1 = 0.902,  val_acc_1 = 0.897    --  train_acc_2 = 0.894,  val_acc_2 = 0.902
# 8  - conf_ID: lyNbIEiT   ****  --  train_acc_1 = 0.868,  val_acc_1 = 0.895    --  train_acc_2 = 0.873,  val_acc_2 = 0.9
# 9  - conf_ID: czbiFRyw   ****  --  train_acc_1 = 0.89,   val_acc_1 = 0.9      --  train_acc_2 = 0.882,  val_acc_2 = 0.902
# 10 - conf_ID: WgQueOGY   ****  --  train_acc_1 = 0.857,  val_acc_1 = 0.894    --  train_acc_2 = 0.865,  val_acc_2 = 0.901
# 11 - conf_ID: fNvwEeqp   ****  --  train_acc_1 = 0.881,  val_acc_1 = 0.895    --  train_acc_2 = 0.868,  val_acc_2 = 0.898
# 12 - conf_ID: LCevdHqK   ****  --  train_acc_1 = 0.886,  val_acc_1 = 0.896    --  train_acc_2 = 0.852,  val_acc_2 = 0.9
# 13 - conf_ID: DSbTEroB   ****  --  train_acc_1 = 0.858,  val_acc_1 = 0.895    --  train_acc_2 = 0.871,  val_acc_2 = 0.899
# 14 - conf_ID: eedWGlsO   ****  --  train_acc_1 = 0.845,  val_acc_1 = 0.894    --  train_acc_2 = 0.861,  val_acc_2 = 0.9
# 15 - conf_ID: qRoiBXSh   ****  --  train_acc_1 = 0.898,  val_acc_1 = 0.896    --  train_acc_2 = 0.894,  val_acc_2 = 0.898
# 16 - conf_ID: mpGRcSUz   ****  --  train_acc_1 = 0.895,  val_acc_1 = 0.893    --  train_acc_2 = 0.874,  val_acc_2 = 0.904
# 17 - conf_ID: MRFKulpP   ****  --  train_acc_1 = 0.866,  val_acc_1 = 0.895    --  train_acc_2 = 0.869,  val_acc_2 = 0.897
# 18 - conf_ID: YfgWXeRN   ****  --  train_acc_1 = 0.855,  val_acc_1 = 0.896    --  train_acc_2 = 0.845,  val_acc_2 = 0.897
# 19 - conf_ID: drZcwylJ   ****  --  train_acc_1 = 0.907,  val_acc_1 = 0.896    --  train_acc_2 = 0.894,  val_acc_2 = 0.899
# 20 - conf_ID: AEHaKkqt   ****  --  train_acc_1 = 0.858,  val_acc_1 = 0.891    --  train_acc_2 = 0.871,  val_acc_2 = 0.899
# 21 - conf_ID: DuZlKOcI   ****  --  train_acc_1 = 0.858,  val_acc_1 = 0.895    --  train_acc_2 = 0.887,  val_acc_2 = 0.898
# 22 - conf_ID: KNreNjHv   ****  --  train_acc_1 = 0.888,  val_acc_1 = 0.89     --  train_acc_2 = 0.869,  val_acc_2 = 0.898
# 23 - conf_ID: TaMHDldg   ****  --  train_acc_1 = 0.863,  val_acc_1 = 0.895    --  train_acc_2 = 0.859,  val_acc_2 = 0.896
# 24 - conf_ID: LtQHqseo   ****  --  train_acc_1 = 0.851,  val_acc_1 = 0.894    --  train_acc_2 = 0.877,  val_acc_2 = 0.901
# 25 - conf_ID: dvTPzars   ****  --  train_acc_1 = 0.865,  val_acc_1 = 0.897    --  train_acc_2 = 0.873,  val_acc_2 = 0.9
# 26 - conf_ID: qByrEFxP   ****  --  train_acc_1 = 0.886,  val_acc_1 = 0.893    --  train_acc_2 = 0.874,  val_acc_2 = 0.898
# 27 - conf_ID: ZqOCwvOX   ****  --  train_acc_1 = 0.866,  val_acc_1 = 0.896    --  train_acc_2 = 0.88,   val_acc_2 = 0.899
# 28 - conf_ID: kIXaNGWM   ****  --  train_acc_1 = 0.901,  val_acc_1 = 0.897    --  train_acc_2 = 0.853,  val_acc_2 = 0.901
# 29 - conf_ID: GUkROnFc   ****  --  train_acc_1 = 0.862,  val_acc_1 = 0.889    --  train_acc_2 = 0.866,  val_acc_2 = 0.893
# 30 - conf_ID: lZGJMafC   ****  --  train_acc_1 = 0.913,  val_acc_1 = 0.89     --  train_acc_2 = 0.886,  val_acc_2 = 0.901
# 31 - conf_ID: mZczjLAQ   ****  --  train_acc_1 = 0.849,  val_acc_1 = 0.893    --  train_acc_2 = 0.878,  val_acc_2 = 0.898
# 32 - conf_ID: rbRTCnAS   ****  --  train_acc_1 = 0.905,  val_acc_1 = 0.891    --  train_acc_2 = 0.899,  val_acc_2 = 0.901
# 33 - conf_ID: UDYZIaxt   ****  --  train_acc_1 = 0.88,   val_acc_1 = 0.892    --  train_acc_2 = 0.892,  val_acc_2 = 0.898
# 34 - conf_ID: GEVCJXob   ****  --  train_acc_1 = 0.904,  val_acc_1 = 0.894    --  train_acc_2 = 0.876,  val_acc_2 = 0.898
# 35 - conf_ID: mlRxUhqa   ****  --  train_acc_1 = 0.906,  val_acc_1 = 0.891    --  train_acc_2 = 0.885,  val_acc_2 = 0.895
# 36 - conf_ID: bftTOoVr   ****  --  train_acc_1 = 0.883,  val_acc_1 = 0.891    --  train_acc_2 = 0.878,  val_acc_2 = 0.898
# 37 - conf_ID: FCSDBQlH   ****  --  train_acc_1 = 0.89,   val_acc_1 = 0.893    --  train_acc_2 = 0.874,  val_acc_2 = 0.895
# 38 - conf_ID: rWdCpWkl   ****  --  train_acc_1 = 0.845,  val_acc_1 = 0.892    --  train_acc_2 = 0.863,  val_acc_2 = 0.902
# 39 - conf_ID: SKjTkhNZ   ****  --  train_acc_1 = 0.933,  val_acc_1 = 0.89     --  train_acc_2 = 0.886,  val_acc_2 = 0.895
# 40 - conf_ID: dqUluagD   ****  --  train_acc_1 = 0.882,  val_acc_1 = 0.895    --  train_acc_2 = 0.889,  val_acc_2 = 0.898
# 41 - conf_ID: qiOILwta   ****  --  train_acc_1 = 0.886,  val_acc_1 = 0.893    --  train_acc_2 = 0.879,  val_acc_2 = 0.896
# 42 - conf_ID: MwtFFCeZ   ****  --  train_acc_1 = 0.845,  val_acc_1 = 0.891    --  train_acc_2 = 0.863,  val_acc_2 = 0.898
# 43 - conf_ID: sJFwMrlm   ****  --  train_acc_1 = 0.892,  val_acc_1 = 0.895    --  train_acc_2 = 0.868,  val_acc_2 = 0.897
# 44 - conf_ID: nZptaPiy   ****  --  train_acc_1 = 0.977,  val_acc_1 = 0.893    --  train_acc_2 = 0.888,  val_acc_2 = 0.9
# 45 - conf_ID: yAbPndzZ   ****  --  train_acc_1 = 0.903,  val_acc_1 = 0.895    --  train_acc_2 = 0.925,  val_acc_2 = 0.898
# 46 - conf_ID: rnHGWvly   ****  --  train_acc_1 = 0.851,  val_acc_1 = 0.895    --  train_acc_2 = 0.848,  val_acc_2 = 0.899
# 47 - conf_ID: vxlsTbeF   ****  --  train_acc_1 = 0.921,  val_acc_1 = 0.892    --  train_acc_2 = 0.871,  val_acc_2 = 0.896
# 48 - conf_ID: CAIlCBAs   ****  --  train_acc_1 = 0.899,  val_acc_1 = 0.891    --  train_acc_2 = 0.903,  val_acc_2 = 0.902
#
# PROCCESS COMPLETE. 48 CONFIGURATIONS WERE SUCCESFULLY EVALUATED.

# %% [markdown]
# ## Resultados

# %%
import pickle
from pandas import DataFrame

with open('./Results/CNN/TR/experiments_2.df', 'rb') as file_handler:
  search_results = pickle.load(file_handler)

search_results.shape
# Out:
# (48, 19)

# %%
search_results.sort_values(by='val_acc_A', ascending=False).head()

# %%
search_results.sort_values(by='val_acc_B', ascending=False).head()

# %%
params_dict = {'dense_layers_sizes':[(400,100),
                      (400,75), 
                      (300,100),
                      (300,75),
                      (200,100),
                      (200,75)]}

# %%
results_utils.plotResultsByParameter1(search_results, 
                       params_dict, 
                       params2plot=['dense_layers_sizes'],
                       metric='val_acc_A')

results_utils.plotResultsByParameter1(search_results, 
                       params_dict, 
                       params2plot=['dense_layers_sizes'],
                       metric='val_acc_B')

# %% [markdown]
# ### Resumen de los resultados
#
# * Mejores combinaciones de kernels sizes: (1,2,3), (2,3,4)
# * lstm_units: [150,200]
# * dense_layers_sizes: [(300,100),**(200,75)**], [**(400,75)**,(200,100)]
# * Optimizador: 'adam-1e-4', 'rmsprop-1e-3'

# %% [markdown]
# # Experimentos con los valores de dropout

# %%
X_train, Y_train = dataset_utils.loadEncodedTrainData(embedding_type='FT3',
                                                 encoding_format='EMB-SEQ',
                                                 labels_to_return=['TR'],
                                                 n_folds=7
                                                 )

# %% [markdown]
# ## Espacio de búsqueda

# %% [markdown]
# **Parámetros de la arquitectura**

# %%
from itertools import product

from itertools import combinations
from itertools import product

dense_layers_sizes = [(400,100)]                    

arch_params = {'kernels_combos':[(1,2,3),(2,3,4)],
              'dense_layers_sizes':dense_layers_sizes,
              'n_filters':[175],
              'conv_layers_activation':['tanh'],
              'pooling_method':['max'],
              'spatial_dropout':[0.3,0.5,0.7],
              'dense_dropout':[0.3,0.5,0.7]} 

arch_params_keys = arch_params.keys()

arch_params_combos = list(product( *arch_params.values() ))          

#arch_params_combos = [params_combo for params_combo in arch_params_combos if params_combo[-2]>=params_combo[-1]]
print('{} arch_params_combos.'.format(len(arch_params_combos)))
# Out:
# 18 arch_params_combos.

# %% [markdown]
# **Parámetros de la arquitectura**

# %%
trainig_params_dict = {'optimizer':['adam-1e-4', 'rmsprop-1e-3'],
                       'batch_size':[512],
                       'max_epochs':[75]}
                        

training_params_keys = trainig_params_dict.keys()
trainig_params_combos = list(product( *trainig_params_dict.values() ))

print('\n{} trainig_params_combos.'.format(len(trainig_params_combos)))
# Out:
# 2 trainig_params_combos.

# %%
search_space = list(product(arch_params_combos, trainig_params_combos))

print('\n{} params combinations in the search_space.'.format(len(search_space)))
# Out:
# 36 params combinations in the search_space.

# %% [markdown]
# ## Escaneo

# %%
results_df = nn_utils.spaceScanner(X_train, Y_train,
                          'TR',
                          convolutionalNetModel, 
                          search_space,
                          arch_params_keys,
                          training_params_keys,
                          fraction2eval=1,
                          n_folds=7,
                          fitting_attemps=1,
                          stop_threshold=1,
                          partial_CV=True,
                          backup_file='./Results/CNN/TR/experiments_3.df',
                          backup_freq=5,
                          save_history_files=True,
                          save_models_as_json=False)

# %% [markdown]
# ## Resultados

# %%
import pickle
from pandas import DataFrame

with open('./Results/CNN/TR/experiments_3.df', 'rb') as file_handler:
  search_results = pickle.load(file_handler)

search_results.shape
# Out:
# (36, 19)

# %%
search_results.sort_values(by='val_acc_A', ascending=False).head(10)

# %%
search_results.sort_values(by='val_acc_B', ascending=False).head(10)

# %%
params_dict = {'spatial_dropout':[0.3,0.5,0.7]}

# %%
results_utils.plotResultsByParameter1(search_results, 
                       params_dict, 
                       params2plot=['spatial_dropout'],
                       metric='val_acc_A',
                       y_limits=[0.88,0.91])

results_utils.plotResultsByParameter1(search_results, 
                       params_dict, 
                       params2plot=['spatial_dropout'],
                       metric='val_acc_B',
                       y_limits=[0.885,0.91])

# %%
params_dict = {'dense_dropout':[0.3,0.5,0.7]}
spatial_dropout_mask = search_results['spatial_dropout'].isin([0.5])

# %%
results_utils.plotResultsByParameter1(search_results.loc[spatial_dropout_mask], 
                       params_dict, 
                       params2plot=['dense_dropout'],
                       metric='val_acc_A',
                       y_limits=[0.885,0.91])

results_utils.plotResultsByParameter1(search_results.loc[spatial_dropout_mask], 
                       params_dict, 
                       params2plot=['dense_dropout'],
                       metric='val_acc_B',
                       y_limits=[0.885,0.91])

# %% [markdown]
# ### Resumen de los resultados
#
# * Mejores combinaciones de kernels sizes: (1,2,3), (2,3,4)
# * lstm_units: [150,200]
# * dense_layers_sizes: [(300,100),**(200,75)**], [**(400,75)**,(200,100)]
# * spatial_dropout: [0.3,**0.5**]
# * dense_dropout:[**0.5**]
#
#
# * Optimizador: 'adam-1e-4', 'rmsprop-1e-3'

# %% [markdown]
# # Experimentos con la función de activación y pooling method

# %% [markdown]
# ## Dataset

# %%
X_train, Y_train = dataset_utils.loadEncodedTrainData(embedding_type='FT3',
                                                 encoding_format='EMB-SEQ',
                                                 labels_to_return=['TR'],
                                                 n_folds=7
                                                 )
# Out:
# FastText 3 - Spanish Unannotated Corpora
# Encoding Format: EMB-SEQ
#
# Process complete
# 5000 train instances retrieved
#
# encodings_dim = (55, 300)

# %% [markdown]
# ## Espacio de búsqueda

# %% [markdown]
# **Parámetros de la arquitectura**

# %%
from itertools import combinations
from itertools import product

dense_layers_sizes = [(400,100)]                    

arch_params = {'kernels_combos':[(1,2,3),(2,3,4)],
              'dense_layers_sizes':dense_layers_sizes,
              'n_filters':[175, 200],
              'conv_layers_activation':['tanh','relu'],
              'pooling_method':['max', 'average'],
              'spatial_dropout':[0.5],
              'dense_dropout':[0.5]} 

arch_params_keys = arch_params.keys()

arch_params_combos = list(product( *arch_params.values() ))          

#arch_params_combos = [params_combo for params_combo in arch_params_combos if params_combo[-2]>=params_combo[-1]]
print('{} arch_params_combos.'.format(len(arch_params_combos)))
# Out:
# 16 arch_params_combos.

# %% [markdown]
# **Parámetros de la arquitectura**

# %%
trainig_params_dict = {'optimizer':['adam-1e-4', 'rmsprop-1e-3'],
                       'batch_size':[512],
                       'max_epochs':[75]}
                        

training_params_keys = trainig_params_dict.keys()
trainig_params_combos = list(product( *trainig_params_dict.values() ))

print('\n{} trainig_params_combos.'.format(len(trainig_params_combos)))
# Out:
# 2 trainig_params_combos.

# %%
search_space = list(product(arch_params_combos, trainig_params_combos))

print('\n{} params combinations in the search_space.'.format(len(search_space)))
# Out:
# 32 params combinations in the search_space.

# %% [markdown]
# ## Escaneo

# %%
results_df = nn_utils.spaceScanner(X_train, Y_train,
                          'TR',
                          convolutionalNetModel, 
                          search_space,
                          arch_params_keys,
                          training_params_keys,
                          fraction2eval=1,
                          n_folds=7,
                          fitting_attemps=1,
                          stop_threshold=1,
                          partial_CV=True,
                          backup_file='./Results/CNN/TR/experiments_4.df',
                          backup_freq=5,
                          save_history_files=True,
                          save_models_as_json=False)
# Out:
# BackupFile: ./Results/CNN/TR/experiments_4.df
# SCANNING SEARCH SPACE
#
# 32 configurations will be evaluated.
# 1  - conf_ID: NcDJzlBO   ****  --  train_acc_1 = 0.896,  val_acc_1 = 0.885    --  train_acc_2 = 0.864,  val_acc_2 = 0.896
# 2  - conf_ID: MwEjvDfW   ****  --  train_acc_1 = 0.872,  val_acc_1 = 0.89     --  train_acc_2 = 0.876,  val_acc_2 = 0.903
# 3  - conf_ID: aqIjJcvy   ****  --  train_acc_1 = 0.822,  val_acc_1 = 0.87     --  train_acc_2 = 0.82,   val_acc_2 = 0.873
# 4  - conf_ID: jfWOaCDd   ****  --  train_acc_1 = 0.828,  val_acc_1 = 0.862    --  train_acc_2 = 0.825,  val_acc_2 = 0.871
# 5  - conf_ID: SWfOfNFH   ****  --  train_acc_1 = 0.865,  val_acc_1 = 0.898    --  train_acc_2 = 0.867,  val_acc_2 = 0.901
# 6  - conf_ID: ECXraioU   ****  --  train_acc_1 = 0.858,  val_acc_1 = 0.893    --  train_acc_2 = 0.849,  val_acc_2 = 0.902
# 7  - conf_ID: qFrPUeey   ****  --  train_acc_1 = 0.889,  val_acc_1 = 0.89     --  train_acc_2 = 0.895,  val_acc_2 = 0.893
# 8  - conf_ID: EGLjIAEz   ****  --  train_acc_1 = 0.886,  val_acc_1 = 0.894    --  train_acc_2 = 0.858,  val_acc_2 = 0.901
# 9  - conf_ID: qfigncTh   ****  --  train_acc_1 = 0.916,  val_acc_1 = 0.9      --  train_acc_2 = 0.879,  val_acc_2 = 0.904
# 10 - conf_ID: kEHMlRwC   ****  --  train_acc_1 = 0.873,  val_acc_1 = 0.893    --  train_acc_2 = 0.863,  val_acc_2 = 0.898
# 11 - conf_ID: uwkjlivb   ****  --  train_acc_1 = 0.83,   val_acc_1 = 0.868    --  train_acc_2 = 0.819,  val_acc_2 = 0.873
# 12 - conf_ID: tfDqwpax   ****  --  train_acc_1 = 0.826,  val_acc_1 = 0.866    --  train_acc_2 = 0.824,  val_acc_2 = 0.873
# 13 - conf_ID: scYFYian   ****  --  train_acc_1 = 0.887,  val_acc_1 = 0.897    --  train_acc_2 = 0.87,   val_acc_2 = 0.901
# 14 - conf_ID: nSSSVfaR   ****  --  train_acc_1 = 0.843,  val_acc_1 = 0.896    --  train_acc_2 = 0.889,  val_acc_2 = 0.901
# 15 - conf_ID: BfpLZfWD   ****  --  train_acc_1 = 0.874,  val_acc_1 = 0.889    --  train_acc_2 = 0.866,  val_acc_2 = 0.893
# 16 - conf_ID: ytxtjVGV   ****  --  train_acc_1 = 0.859,  val_acc_1 = 0.895    --  train_acc_2 = 0.858,  val_acc_2 = 0.903
# 17 - conf_ID: lzHAnbyg   ****  --  train_acc_1 = 0.878,  val_acc_1 = 0.895    --  train_acc_2 = 0.893,  val_acc_2 = 0.9
# 18 - conf_ID: UCoJdQDB   ****  --  train_acc_1 = 0.924,  val_acc_1 = 0.886    --  train_acc_2 = 0.865,  val_acc_2 = 0.896
# 19 - conf_ID: oXaXqmbX   ****  --  train_acc_1 = 0.827,  val_acc_1 = 0.87     --  train_acc_2 = 0.823,  val_acc_2 = 0.873
# 20 - conf_ID: fnwbdXaI   ****  --  train_acc_1 = 0.833,  val_acc_1 = 0.863    --  train_acc_2 = 0.822,  val_acc_2 = 0.869
# 21 - conf_ID: BYavriOY   ****  --  train_acc_1 = 0.876,  val_acc_1 = 0.893    --  train_acc_2 = 0.904,  val_acc_2 = 0.898
# 22 - conf_ID: tnYEJhDx   ****  --  train_acc_1 = 0.928,  val_acc_1 = 0.881    --  train_acc_2 = 0.86,   val_acc_2 = 0.901
# 23 - conf_ID: qpJWKthg   ****  --  train_acc_1 = 0.922,  val_acc_1 = 0.89     --  train_acc_2 = 0.885,  val_acc_2 = 0.894
# 24 - conf_ID: fEymegdH   ****  --  train_acc_1 = 0.888,  val_acc_1 = 0.888    --  train_acc_2 = 0.855,  val_acc_2 = 0.901
# 25 - conf_ID: ZzjsuitN   ****  --  train_acc_1 = 0.9,    val_acc_1 = 0.891    --  train_acc_2 = 0.894,  val_acc_2 = 0.896
# 26 - conf_ID: LZQEHsvV   ****  --  train_acc_1 = 0.849,  val_acc_1 = 0.891    --  train_acc_2 = 0.871,  val_acc_2 = 0.898
# 27 - conf_ID: eZqXoxRP   ****  --  train_acc_1 = 0.829,  val_acc_1 = 0.871    --  train_acc_2 = 0.825,  val_acc_2 = 0.875
# 28 - conf_ID: VcMcAGAx   ****  --  train_acc_1 = 0.813,  val_acc_1 = 0.862    --  train_acc_2 = 0.821,  val_acc_2 = 0.873
# 29 - conf_ID: bjFKDMQC   ****  --  train_acc_1 = 0.878,  val_acc_1 = 0.896    --  train_acc_2 = 0.869,  val_acc_2 = 0.898
# 30 - conf_ID: mEHijDsh   ****  --  train_acc_1 = 0.863,  val_acc_1 = 0.897    --  train_acc_2 = 0.864,  val_acc_2 = 0.901
# 31 - conf_ID: wKbwehxr   ****  --  train_acc_1 = 0.912,  val_acc_1 = 0.888    --  train_acc_2 = 0.912,  val_acc_2 = 0.894
# 32 - conf_ID: WgZDeImM   ****  --  train_acc_1 = 0.849,  val_acc_1 = 0.894    --  train_acc_2 = 0.865,  val_acc_2 = 0.899
#
# PROCCESS COMPLETE. 32 CONFIGURATIONS WERE SUCCESFULLY EVALUATED.

# %% [markdown]
# ## Resultados

# %%
results_list = ['./Results/CNN/HS_experiments_4_batch_1.df',
                './Results/CNN/HS_experiments_4_batch_2.df',
                './Results/CNN/HS_experiments_4_batch_3.df',
                './Results/CNN/HS_experiments_4_batch_4.df']

results_df = results_utils.mergeDataFrames(results_list, './Results/CNN/HS_experiments_4.df')

# %%
import pickle
from pandas import DataFrame

with open('./Results/CNN/TR/experiments_4.df', 'rb') as file_handler:
  search_results = pickle.load(file_handler)

search_results.shape
# Out:
# (32, 19)

# %%
search_results.sort_values(by='val_acc_A', ascending=False).head(10)

# %%
search_results.sort_values(by='val_acc_B', ascending=False).head(10)

# %%
params_dict = {'conv_layers_activation':['tanh', 'relu']}

# %%
results_utils.plotResultsByParameter1(search_results, 
                       params_dict, 
                       params2plot=['conv_layers_activation'],
                       metric='val_acc_A')

results_utils.plotResultsByParameter1(search_results, 
                       params_dict, 
                       params2plot=['conv_layers_activation'],
                       metric='val_acc_B')

# %%
params_dict = {'pooling_method':['max', 'average']}

# %%
results_utils.plotResultsByParameter1(search_results, 
                       params_dict, 
                       params2plot=['pooling_method'],
                       metric='val_acc_A')

results_utils.plotResultsByParameter1(search_results, 
                       params_dict, 
                       params2plot=['pooling_method'],
                       metric='val_acc_B')

# %%
params_dict = {'n_filters':[175, 200]}

# %%
results_utils.plotResultsByParameter1(search_results, 
                       params_dict, 
                       params2plot=['n_filters'],
                       metric='val_acc_A')

results_utils.plotResultsByParameter1(search_results, 
                       params_dict, 
                       params2plot=['n_filters'],
                       metric='val_acc_B')

# %% [markdown]
# ### Resumen de los resultados
#
# * Mejores combinaciones de kernels sizes: (1,2,3), (2,3,4)
# * lstm_units: [150,200]
# * dense_layers_sizes: [(300,100),**(200,75)**], [**(400,75)**,(200,100)]
# * cnn_activation: ['tanh', **'relu'**]
# * pooling_method: 'max'
# * spatial_dropout: [0.3,**0.5**]
# * dense_dropout:[**0.5**]
#
#
# * Optimizador: 'adam-1e-4', 'rmsprop-1e-3'

# %% [markdown]
# # Experimentos con el batch_size

# %% [markdown]
# ## Dataset

# %%
X_train, Y_train = dataset_utils.loadEncodedTrainData(embedding_type='FT3',
                                                 encoding_format='EMB-SEQ',
                                                 labels_to_return=['TR'],
                                                 n_folds=7
                                                 )
# Out:
# FastText 3 - Spanish Unannotated Corpora
# Encoding Format: EMB-SEQ
#
# Process complete
# 5000 train instances retrieved
#
# encodings_dim = (55, 300)

# %% [markdown]
# ## Espacio de búsqueda

# %% [markdown]
# **Parámetros de la arquitectura**

# %%
from itertools import combinations
from itertools import product

dense_layers_sizes = [(400,100)]                    

arch_params = {'kernels_combos':[(1,2,3),(2,3,4)],
              'dense_layers_sizes':dense_layers_sizes,
              'n_filters':[175, 200],
              'conv_layers_activation':['relu'],
              'pooling_method':['max'],
              'spatial_dropout':[0.5],
              'dense_dropout':[0.5]} 

arch_params_keys = arch_params.keys()

arch_params_combos = list(product( *arch_params.values() ))          

#arch_params_combos = [params_combo for params_combo in arch_params_combos if params_combo[-2]>=params_combo[-1]]
print('{} arch_params_combos.'.format(len(arch_params_combos)))
# Out:
# 4 arch_params_combos.

# %% [markdown]
# **Parámetros de la arquitectura**

# %%
trainig_params_dict = {'optimizer':['adam-1e-4', 'rmsprop-1e-3'],
                       'batch_size':[256,512,1024],
                       'max_epochs':[75]}
                        

training_params_keys = trainig_params_dict.keys()
trainig_params_combos = list(product( *trainig_params_dict.values() ))

print('\n{} trainig_params_combos.'.format(len(trainig_params_combos)))
# Out:
# 6 trainig_params_combos.

# %%
search_space = list(product(arch_params_combos, trainig_params_combos))

print('\n{} params combinations in the search_space.'.format(len(search_space)))
# Out:
# 24 params combinations in the search_space.

# %% [markdown]
# ## Escaneo

# %%
results_df = nn_utils.spaceScanner(X_train, Y_train,
                          'TR',
                          convolutionalNetModel, 
                          search_space,
                          arch_params_keys,
                          training_params_keys,
                          fraction2eval=1,
                          n_folds=7,
                          fitting_attemps=1,
                          stop_threshold=1,
                          partial_CV=True,
                          backup_file='./Results/CNN/TR/experiments_5.df',
                          backup_freq=5,
                          save_history_files=True,
                          save_models_as_json=False)
# Out:
# BackupFile: ./Results/CNN/TR/experiments_5.df
# SCANNING SEARCH SPACE
#
# 24 configurations will be evaluated.
# 1  - conf_ID: LVLhjiNa   ****  --  train_acc_1 = 0.842,  val_acc_1 = 0.898    --  train_acc_2 = 0.85,   val_acc_2 = 0.902
# 2  - conf_ID: IhPrGmDl   ****  --  train_acc_1 = 0.907,  val_acc_1 = 0.893    --  train_acc_2 = 0.864,  val_acc_2 = 0.897
# 3  - conf_ID: ZTJXdNRA   ****  --  train_acc_1 = 0.9,    val_acc_1 = 0.897    --  train_acc_2 = 0.866,  val_acc_2 = 0.901
# 4  - conf_ID: pRjjeEgr   ****  --  train_acc_1 = 0.869,  val_acc_1 = 0.89     --  train_acc_2 = 0.865,  val_acc_2 = 0.897
# 5  - conf_ID: PutfgsTI   ****  --  train_acc_1 = 0.909,  val_acc_1 = 0.885    --  train_acc_2 = 0.86,   val_acc_2 = 0.9
# 6  - conf_ID: yqLhBzvT   ****  --  train_acc_1 = 0.865,  val_acc_1 = 0.891    --  train_acc_2 = 0.836,  val_acc_2 = 0.9
# 7  - conf_ID: yEdUodTK   ****  --  train_acc_1 = 0.889,  val_acc_1 = 0.895    --  train_acc_2 = 0.89,   val_acc_2 = 0.9
# 8  - conf_ID: ePJPScXq   ****  --  train_acc_1 = 0.879,  val_acc_1 = 0.898    --  train_acc_2 = 0.86,   val_acc_2 = 0.902
# 9  - conf_ID: CtkKnNJg   ****  --  train_acc_1 = 0.866,  val_acc_1 = 0.898    --  train_acc_2 = 0.86,   val_acc_2 = 0.901
# 10 - conf_ID: TLhqlXvi   ****  --  train_acc_1 = 0.887,  val_acc_1 = 0.895    --  train_acc_2 = 0.87,   val_acc_2 = 0.9
# 11 - conf_ID: XmsSNuuu   ****  --  train_acc_1 = 0.864,  val_acc_1 = 0.895    --  train_acc_2 = 0.861,  val_acc_2 = 0.9
# 12 - conf_ID: ZKNHjeaB   ****  --  train_acc_1 = 0.902,  val_acc_1 = 0.897    --  train_acc_2 = 0.855,  val_acc_2 = 0.901
# 13 - conf_ID: xnAvFERm   ****  --  train_acc_1 = 0.882,  val_acc_1 = 0.892    --  train_acc_2 = 0.896,  val_acc_2 = 0.896
# 14 - conf_ID: OJYNuiLz   ****  --  train_acc_1 = 0.871,  val_acc_1 = 0.896    --  train_acc_2 = 0.887,  val_acc_2 = 0.901
# 15 - conf_ID: RlKWPHCX   ****  --  train_acc_1 = 0.874,  val_acc_1 = 0.894    --  train_acc_2 = 0.873,  val_acc_2 = 0.897
# 16 - conf_ID: cVwTZaYA   ****  --  train_acc_1 = 0.888,  val_acc_1 = 0.891    --  train_acc_2 = 0.88,   val_acc_2 = 0.901
# 17 - conf_ID: uzpiUdeN   ****  --  train_acc_1 = 0.884,  val_acc_1 = 0.892    --  train_acc_2 = 0.872,  val_acc_2 = 0.896
# 18 - conf_ID: NlhEgPZJ   ****  --  train_acc_1 = 0.944,  val_acc_1 = 0.887    --  train_acc_2 = 0.863,  val_acc_2 = 0.902
# 19 - conf_ID: rQwVQwRC   ****  --  train_acc_1 = 0.863,  val_acc_1 = 0.897    --  train_acc_2 = 0.86,   val_acc_2 = 0.898
# 20 - conf_ID: WTzvwPyH   ****  --  train_acc_1 = 0.883,  val_acc_1 = 0.894    --  train_acc_2 = 0.881,  val_acc_2 = 0.898
# 21 - conf_ID: FSGqPylp   ****  --  train_acc_1 = 0.903,  val_acc_1 = 0.893    --  train_acc_2 = 0.88,   val_acc_2 = 0.896
# 22 - conf_ID: AVPWVVBh   ****  --  train_acc_1 = 0.921,  val_acc_1 = 0.883    --  train_acc_2 = 0.875,  val_acc_2 = 0.898
# 23 - conf_ID: JePDnUFE   ****  --  train_acc_1 = 0.857,  val_acc_1 = 0.891    --  train_acc_2 = 0.854,  val_acc_2 = 0.899
# 24 - conf_ID: MkbFmnAx   ****  --  train_acc_1 = 0.876,  val_acc_1 = 0.898    --  train_acc_2 = 0.869,  val_acc_2 = 0.901
#
# PROCCESS COMPLETE. 24 CONFIGURATIONS WERE SUCCESFULLY EVALUATED.

# %% [markdown]
# ## Resultados

# %%
results_list = ['./Results/CNN/HS_experiments_5_batch_1.df',
                './Results/CNN/HS_experiments_5_batch_2.df',
                './Results/CNN/HS_experiments_5_batch_3.df']

results_df = results_utils.mergeDataFrames(results_list, './Results/CNN/HS_experiments_5.df')

# %%
import pickle
from pandas import DataFrame

with open('./Results/CNN/TR/experiments_5.df', 'rb') as file_handler:
  search_results = pickle.load(file_handler)

search_results.shape
# Out:
# (24, 19)

# %%
search_results.sort_values(by='val_acc_A', ascending=False).head(10)

# %%
search_results.sort_values(by='val_acc_B', ascending=False).head(10)

# %%
params_dict = {'batch_size':[256,512,1024]}

# %%
results_utils.plotResultsByParameter1(search_results, 
                       params_dict, 
                       params2plot=['batch_size'],
                       metric='val_acc_A')

results_utils.plotResultsByParameter1(search_results, 
                       params_dict, 
                       params2plot=['batch_size'],
                       metric='val_acc_B')

# %%
params_dict = {'n_filters':[175,200]}

# %%
results_utils.plotResultsByParameter1(search_results, 
                       params_dict, 
                       params2plot=['n_filters'],
                       metric='val_acc_A')

results_utils.plotResultsByParameter1(search_results, 
                       params_dict, 
                       params2plot=['n_filters'],
                       metric='val_acc_B')

# %% [markdown]
# ### Resumen de los resultados
#
# * Mejores combinaciones de kernels sizes: (1,2,3), (2,3,4)
# * lstm_units: [150,200]
# * dense_layers_sizes: [(300,100),**(200,75)**], [**(400,75)**,(200,100)]
# * cnn_activation: ['tanh', **'relu'**]
# * pooling_method: 'max'
# * spatial_dropout: [0.3,**0.5**]
# * dense_dropout:[**0.5**]
#
#
# * Optimizador: 'adam-1e-4', 'rmsprop-1e-3'
# * batch_size: [256,**1024**]

# %% [markdown]
# # Experimento final

# %% [markdown]
# ## Dataset

# %%
X_train, Y_train = dataset_utils.loadEncodedTrainData(embedding_type='FT3',
                                                 encoding_format='EMB-SEQ',
                                                 labels_to_return=['HTA'],
                                                 n_folds=7
                                                 )
# Out:
# FastText 3 - Spanish Unannotated Corpora
# Encoding Format: EMB-SEQ
#
# Process complete
# 5000 train instances retrieved
#
# encodings_dim = (55, 300)

# %% [markdown]
# ## Espacio de búsqueda

# %% [markdown]
# **Parámetros de la arquitectura**

# %%
from itertools import combinations
from itertools import product

dense_layers_sizes = [(400,100)]                     

arch_params = {'kernels_combos':[(1,2,3),(2,3,4)],
              'dense_layers_sizes':dense_layers_sizes,
              'n_filters':[175, 200],
              'conv_layers_activation':['relu'],
              'pooling_method':['max'],
              'spatial_dropout':[0.5],
              'dense_dropout':[0.5]} 

arch_params_keys = arch_params.keys()

arch_params_combos = list(product( *arch_params.values() ))          

#arch_params_combos = [params_combo for params_combo in arch_params_combos if params_combo[-2]>=params_combo[-1]]
print('{} arch_params_combos.'.format(len(arch_params_combos)))
# Out:
# 4 arch_params_combos.

# %% [markdown]
# **Parámetros de la arquitectura**

# %%
trainig_params_dict = {'optimizer':['adam-1e-4', 'rmsprop-1e-3'],
                       'batch_size':[1024],
                       'max_epochs':[75]}
                        

training_params_keys = trainig_params_dict.keys()
trainig_params_combos = list(product( *trainig_params_dict.values() ))

print('\n{} trainig_params_combos.'.format(len(trainig_params_combos)))
# Out:
# 2 trainig_params_combos.

# %%
search_space = list(product(arch_params_combos, trainig_params_combos))

print('\n{} params combinations in the search_space.'.format(len(search_space)))
# Out:
# 8 params combinations in the search_space.

# %% [markdown]
# ## Escaneo

# %%
results_df = nn_utils.spaceScanner(X_train, Y_train,
                          'TR',
                          convolutionalNetModel, 
                          search_space,
                          arch_params_keys,
                          training_params_keys,
                          fraction2eval=1,
                          n_folds=7,
                          fitting_attemps=1,
                          stop_threshold=1,
                          partial_CV=False,
                          backup_file='./Results/CNN/TR/experiments_6.df',
                          backup_freq=1,
                          save_history_files=True,
                          save_models_as_json=True,
                          save_weights=True)
# Out:
# BackupFile: ./Results/CNN/TR/experiments_6.df
# SCANNING SEARCH SPACE
#
# 8 configurations will be evaluated.
# 1 - conf_ID: TfFFXlkd   *******  --  train_acc_1 = 0.885,  val_acc_1 = 0.897    --  train_acc_2 = 0.873,  val_acc_2 = 0.899
# 2 - conf_ID: oRGmNoZx   *******  --  train_acc_1 = 0.886,  val_acc_1 = 0.893    --  train_acc_2 = 0.847,  val_acc_2 = 0.903
# 3 - conf_ID: sWquCUHY   *******  --  train_acc_1 = 0.863,  val_acc_1 = 0.894    --  train_acc_2 = 0.887,  val_acc_2 = 0.899
# 4 - conf_ID: oziyYwlg   *******  --  train_acc_1 = 0.909,  val_acc_1 = 0.89     --  train_acc_2 = 0.85,   val_acc_2 = 0.903
# 5 - conf_ID: XKWyJjCp   *******  --  train_acc_1 = 0.915,  val_acc_1 = 0.895    --  train_acc_2 = 0.885,  val_acc_2 = 0.9
# 6 - conf_ID: pTXwsqCt   *******  --  train_acc_1 = 0.899,  val_acc_1 = 0.894    --  train_acc_2 = 0.885,  val_acc_2 = 0.903
# 7 - conf_ID: wrfidhVN   *******  --  train_acc_1 = 0.862,  val_acc_1 = 0.896    --  train_acc_2 = 0.883,  val_acc_2 = 0.901
# 8 - conf_ID: IORQHGKQ   *******  --  train_acc_1 = 0.899,  val_acc_1 = 0.891    --  train_acc_2 = 0.89,   val_acc_2 = 0.898
#
# PROCCESS COMPLETE. 8 CONFIGURATIONS WERE SUCCESFULLY EVALUATED.

# %% [markdown]
# ## Resultados

# %%
results_list = ['./Results/CNN/HS_experiments_6f_batch_1.df',
                './Results/CNN/HS_experiments_6f_batch_2.df',
                './Results/CNN/HS_experiments_6f_batch_3.df',
                './Results/CNN/HS_experiments_6f_batch_4.df',
                './Results/CNN/HS_experiments_6f_batch_5.df',
                './Results/CNN/HS_experiments_6f_batch_6.df']

results_df = results_utils.mergeDataFrames(results_list, './Results/CNN/HS_experiments_6f.df')

# %%
import pickle
from pandas import DataFrame

with open('./Results/CNN/TR/experiments_6.df', 'rb') as file_handler:
  search_results = pickle.load(file_handler)

search_results.shape
# Out:
# (8, 19)

# %%
search_results.sort_values(by='val_acc_A', ascending=False).head()
# Out:
#     conf_ID kernels_combos  ... train_acc_B  val_acc_B
# 0  TfFFXlkd      (1, 2, 3)  ...    0.873333   0.898999
# 6  wrfidhVN      (2, 3, 4)  ...    0.883466   0.900599
# 4  XKWyJjCp      (2, 3, 4)  ...    0.884601   0.899599
# 2  sWquCUHY      (1, 2, 3)  ...    0.886999   0.898800
# 5  pTXwsqCt      (2, 3, 4)  ...    0.884864   0.902801
#
# [5 rows x 19 columns]

# %%
search_results.sort_values(by='val_acc_B', ascending=False).head()
# Out:
#     conf_ID kernels_combos  ... train_acc_B  val_acc_B
# 3  oziyYwlg      (1, 2, 3)  ...    0.849967   0.903202
# 1  oRGmNoZx      (1, 2, 3)  ...    0.847101   0.903001
# 5  pTXwsqCt      (2, 3, 4)  ...    0.884864   0.902801
# 6  wrfidhVN      (2, 3, 4)  ...    0.883466   0.900599
# 4  XKWyJjCp      (2, 3, 4)  ...    0.884601   0.899599
#
# [5 rows x 19 columns]
