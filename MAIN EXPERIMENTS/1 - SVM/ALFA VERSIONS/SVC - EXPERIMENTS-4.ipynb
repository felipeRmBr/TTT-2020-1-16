# %% [markdown]
# # Settign up

# %% [markdown]
# ## Conexión a google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd ./drive/MyDrive/Colab Notebooks/
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# %pwd
# Out:
# '/content/drive/My Drive/Colab Notebooks'

# %% [markdown]
# ## Instalar microTC

# %%
# %pip install git+https://github.com/felipeRmBr/microtc.git#egg=microtc

# %% [markdown]
# ## Importar módulos *_utils

# %%
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/')
from my_utils import dataset_utils
from my_utils import eval_utils
from my_utils import svc_utils
from my_utils import results_utils

import pickle

# %% [markdown]
# ## Importar el dataset

# %%
X_train, Y_train = dataset_utils.importTrainDataForSVM()

# %% [markdown]
# # Experimentos para ajustar el factor de penalización

# %% [markdown]
# ## Escaneo

# %%
from itertools import product
from microtc.textmodel import TextModel

tm_parameters_keys = ['num_option',
 'usr_option',
 'url_option',
 'hashtag_option',
 'del_punc',
 'del_dup',
 'del_diac',
 'token_list',
 'weighting']
 
svm_params_keys = ['kernel', 'C']

# %% [markdown]
# ### HS -linear kernel

# %%
# HS linear kernel
tm_settings_list = [ ['group', 'delete', 'group', 'delete', False, False, True, [-3, -2, -1, 3, 7], 'tfidf'],
['group', 'delete', 'group', 'delete', False, False, True, [-2, -1, 3, 7], 'tfidf'],
['group', 'delete', 'group', 'delete', True, False, True, [-2, -1, 3, 5, 7], 'tfidf'],
['group', 'delete', 'delete', 'delete', True, False, True, [-3, -2, -1, 3, 6], 'tfidf'],
['group', 'delete', 'group', 'delete', True, False, True, [-3, -1, 3, 5, 7], 'tfidf'] ]

# svm_search_space
svm_params = {'kernel':['linear'], 'C':[1.41, 2, 2.82, 4, 5.65]}
svm_search_space = list(product(*svm_params.values()))
print(len(svm_search_space), ' combination(s) in svm_search_space')

# scanning for classifiers with linear kernel
_ = svcSpaceScanner(X_train, Y_train,
                    'HS',
                    tm_settings_list,
                    tm_parameters_keys,
                    svm_search_space,
                    svm_params_keys,
                    n_folds=7,
                    metrics=['acc'],
                    partial_CV=False,
                    backup_file=f'./Results/SVC/phase-4/HS_linear.df',
                    save_textmodels=True,
                    save_classifiers=True)

# %% [markdown]
# ### HS - sigmoid kernel

# %%
from itertools import product

# HS sigmoid kernel
tm_settings_list = [ ['group', 'delete', 'group', 'delete', False, False, True, [-3, -2, -1, 3, 7], 'tfidf'],
['group', 'delete', 'group', 'delete', False, False, True, [-2, -1, 3, 7], 'tfidf'],
['group', 'delete', 'group', 'delete', True, False, False, [-3, -1, 3, 7], 'tfidf'],
['group', 'delete', 'group', 'delete', False, False, True, [-3, -2, -1, 3, 6], 'tfidf'],
['group', 'delete', 'group', 'delete', False, False, True, [-2, -1, 3, 6, 7], 'tfidf'] ]

# svm_search_space
svm_params = {'kernel':['sigmoid'], 'C':[1.41, 2, 2.82, 4, 5.65]}
svm_search_space = list(product(*svm_params.values()))
print(len(svm_search_space), ' combination(s) in svm_search_space')

# scanning for classifiers with linear kernel
_ = svcSpaceScanner(X_train, Y_train,
                    'HS',
                    tm_settings_list,
                    tm_parameters_keys,
                    svm_search_space,
                    svm_params_keys,
                    n_folds=7,
                    metrics=['acc'],
                    partial_CV=False,
                    backup_file=f'./Results/SVC/phase-4/HS_sigmoid.df',
                    save_textmodels=True,
                    save_classifiers=True)

# %% [markdown]
# ### TR -linear kernel

# %%
from itertools import product
from microtc.textmodel import TextModel

tm_parameters_keys = ['num_option',
 'usr_option',
 'url_option',
 'hashtag_option',
 'del_punc',
 'del_dup',
 'del_diac',
 'token_list',
 'weighting']
 
svm_params_keys = ['kernel', 'C']

# TR linear kernel
tm_settings_list = [ ['group', 'delete', 'group', 'delete', False, False, True, [-3, -2, -1, 3, 6], 'tfidf'],
 ['group', 'delete', 'group', 'delete', False, False, True, [-1, 3, 7], 'tfidf'],
 ['group', 'delete', 'group', 'delete', True, False, True, [-3, -1, 3, 7], 'tfidf'],
 ['group', 'delete', 'group', 'delete', False, False, True, [-2, -1, 3, 6], 'tfidf'],
 ['group', 'delete', 'group', 'delete', False, False, True, [-3, -2, -1, 3, 7], 'tfidf'] ]

# svm_search_space
svm_params = {'kernel':['linear'], 'C':[1.41, 2, 2.82, 4, 5.65]}
svm_search_space = list(product(*svm_params.values()))
print(len(svm_search_space), ' combination(s) in svm_search_space')


# scanning for classifiers with linear kernel
_ = svc_utils.svcSpaceScanner(X_train, Y_train,
                    'TR',
                    tm_settings_list,
                    tm_parameters_keys,
                    svm_search_space,
                    svm_params_keys,
                    n_folds=7,
                    metrics=['acc'],
                    partial_CV=False,
                    backup_file=f'./Results/SVC/phase-4/TR_linear.df',
                    save_textmodels=True,
                    save_classifiers=True)

# %% [markdown]
# ### TR - sigmoid kernel

# %%
from itertools import product

# TR sigmoid kernel
tm_settings_list = [['group', 'delete', 'delete', 'delete', False, False, True, [-3, -1, 3, 7], 'tfidf'],
 ['group', 'delete', 'group', 'delete', False, False, True, [-3, -2, -1, 3, 6], 'tfidf'],
 ['group', 'delete', 'group', 'delete', False, False, True, [-3, -2, -1, 3, 7], 'tfidf'],
 ['group', 'delete', 'group', 'delete', False, False, True, [-3, -1, 3, 6, 7], 'tfidf'],
 ['group', 'delete', 'group', 'delete', False, False, True, [-2, -1, 3, 5, 7], 'tfidf'] ]

# svm_search_space
svm_params = {'kernel':['sigmoid'], 'C':[1.41, 2, 2.82, 4, 5.65]}
svm_search_space = list(product(*svm_params.values()))
print(len(svm_search_space), ' combination(s) in svm_search_space')

# scanning for classifiers with sigmoid kernel
_ = svc_utils.svcSpaceScanner(X_train, Y_train,
                    'TR',
                    tm_settings_list,
                    tm_parameters_keys,
                    svm_search_space,
                    svm_params_keys,
                    n_folds=7,
                    metrics=['acc'],
                    partial_CV=False,
                    backup_file=f'./Results/SVC/phase-4/TR_sigmoid.df',
                    save_textmodels=True,
                    save_classifiers=True)

# %% [markdown]
# ### AG -linear kernel

# %%
from itertools import product
from microtc.textmodel import TextModel

tm_parameters_keys = ['num_option',
 'usr_option',
 'url_option',
 'hashtag_option',
 'del_punc',
 'del_dup',
 'del_diac',
 'token_list',
 'weighting']
 
svm_params_keys = ['kernel', 'C']

# AG linear kernel
tm_settings_list = [['group', 'delete', 'group', 'delete', False, False, True, [-2, -1, 3, 7], 'tfidf'],
 ['group', 'delete', 'group', 'delete', False, False, True, [-3, -1, 3, 7], 'tfidf'],
 ['group', 'delete', 'group', 'delete', False, False, True, [-2, -1, 3, 6, 7], 'tfidf'],
 ['group', 'delete', 'group', 'delete', False, False, True, [-1, 3, 7], 'tfidf'],
 ['group', 'delete', 'group', 'delete', True, False, True, [-3, -1, 3, 6, 7], 'tfidf'] ]


# svm_search_space
svm_params = {'kernel':['linear'], 'C':[1.41, 2, 2.82, 4, 5.65]}
svm_search_space = list(product(*svm_params.values()))
print(len(svm_search_space), ' combination(s) in svm_search_space')


# scanning for classifiers with linear kernel
_ = svc_utils.svcSpaceScanner(X_train, Y_train,
                    'AG',
                    tm_settings_list,
                    tm_parameters_keys,
                    svm_search_space,
                    svm_params_keys,
                    n_folds=7,
                    metrics=['acc'],
                    partial_CV=False,
                    backup_file=f'./Results/SVC/phase-4/AG_linear.df',
                    save_textmodels=True,
                    save_classifiers=True)

# %% [markdown]
# ### AG - sigmoid kernel

# %%
from itertools import product

# TR sigmoid kernel
tm_settings_list = [ ['group', 'delete', 'group', 'delete', False, False, True, [-3, -2, -1, 3, 7], 'tfidf'],
 ['group', 'delete', 'delete', 'delete', False, False, True, [-2, -1, 3, 7], 'tfidf'],
 ['group', 'delete', 'group', 'delete', False, False, True, [-2, -1, 3, 6, 7], 'tfidf'],
 ['group', 'delete', 'group', 'delete', True, False, False, [-3, -1, 3, 7], 'tfidf'],
 ['group', 'delete', 'delete', 'delete', False, False, True, [-3, -1, 3, 6, 7], 'tfidf'] ]

# svm_search_space
svm_params = {'kernel':['sigmoid'], 'C':[1.41, 2, 2.82, 4, 5.65]}
svm_search_space = list(product(*svm_params.values()))
print(len(svm_search_space), ' combination(s) in svm_search_space')

# scanning for classifiers with sigmoid kernel
_ = svc_utils.svcSpaceScanner(X_train, Y_train,
                    'AG',
                    tm_settings_list,
                    tm_parameters_keys,
                    svm_search_space,
                    svm_params_keys,
                    n_folds=7,
                    metrics=['acc'],
                    partial_CV=False,
                    backup_file=f'./Results/SVC/phase-4/AG_sigmoid.df',
                    save_textmodels=True,
                    save_classifiers=True)

# %% [markdown]
# ### HTA - linear kernel

# %%
from itertools import product
from microtc.textmodel import TextModel

tm_parameters_keys = ['num_option',
 'usr_option',
 'url_option',
 'hashtag_option',
 'del_punc',
 'del_dup',
 'del_diac',
 'token_list',
 'weighting']
 
svm_params_keys = ['kernel', 'C']


# HTA linear kernel
tm_settings_list = [ ['group', 'delete', 'group', 'group', True, False, True, [-3, -2, -1, 3], 'tfidf'],
['group', 'delete', 'group', 'delete', True, False, True, [-3, -2, -1, 3, 4], 'tfidf'],
['group', 'delete', 'group', 'group', True, False, True, [-2, -1, 3], 'tfidf'],
['group', 'delete', 'group', 'group', True, False, True, [-3, -1, 3], 'tfidf'],
['group', 'delete', 'group', 'group', True, False, True, [-2, -1, 3, 4, 7], 'tfidf'] ]

# svm_search_space
svm_params = {'kernel':['linear'], 'C':[1.41, 2, 2.82, 4, 5.65]}
svm_search_space = list(product(*svm_params.values()))
print(len(svm_search_space), ' combination(s) in svm_search_space')

# scanning for classifiers with linear kernel
_ = svcSpaceScanner(X_train, Y_train,
                    'HTA',
                    tm_settings_list,
                    tm_parameters_keys,
                    svm_search_space,
                    svm_params_keys,
                    n_folds=7,
                    metrics=['acc'],
                    partial_CV=False,
                    backup_file=f'./Results/SVC/phase-4/HTA_linear.df',
                    save_textmodels=True,
                    save_classifiers=True)

# %% [markdown]
# ### HTA - sigmoid kernel

# %%
from itertools import product
from microtc.textmodel import TextModel

tm_parameters_keys = ['num_option',
 'usr_option',
 'url_option',
 'hashtag_option',
 'del_punc',
 'del_dup',
 'del_diac',
 'token_list',
 'weighting']
 
svm_params_keys = ['kernel', 'C']

configurations_ids = ['KAcOYq', 'bmCbAB', 'pcPfNL', 'wNOXbH', 'hVEaUj']
textmodels_ids = ['djwYeF', 'TqHwoB', 'sUlSKy', 'CgdcXu', 'oDWZfJ']

# HTA sigmoid kernel
tm_settings_list = [ ['group', 'delete', 'delete', 'delete', False, False, True, [-3, -1, 3, 7], 'tfidf'],
['group', 'group', 'group', 'delete', True, False, True, [-1, 3, 7], 'tfidf'],
['group', 'delete', 'delete', 'delete', False, False, True, [-3, -2, -1, 3, 6], 'tfidf'],
['group', 'group', 'group', 'delete', True, False, True, [-3, -1, 3, 6], 'tfidf'],
['group', 'delete', 'group', 'delete', False, False, True, [-3, -2, -1, 3, 5], 'tfidf'] ]

# svm_search_space
svm_params = {'kernel':['sigmoid'], 'C':[1.41, 2, 2.82, 4, 5.65]}
svm_search_space = list(product(*svm_params.values()))
print(len(svm_search_space), ' combination(s) in svm_search_space')


# scanning for classifiers with linear kernel
_ = svcSpaceScanner(X_train, Y_train,
                    'HTA',
                    tm_settings_list,
                    tm_parameters_keys,
                    svm_search_space,
                    svm_params_keys,
                    n_folds=7,
                    metrics=['acc'],
                    partial_CV=False,
                    backup_file=f'./Results/SVC/phase-4/HTA_sigmoid.df',
                    save_textmodels=True,
                    save_classifiers=True)

# %% [markdown]
# ## Resultados

# %% [markdown]
# ### HS -linear kernel

# %%
import pickle

# %%
with open('./Results/SVC/phase-4/HS_linear.df', 'rb') as file_handler:
  results_df = pickle.load(file_handler)

# %%
results_df.loc[:,['conf_ID', 'tm_ID', 'C', 'mean_acc', 'mean_val_acc']]

# %%
C_mask = results_df['C']==1.41
rows2return = 'num_option', 'usr_option', 'url_option', 'hashtag_option', 'del_dup', 'delete_diac', 
results_df.loc[C_mask, 'mean_val_acc']
# Out:
# 0     0.775233
# 5     0.775100
# 10    0.774500
# 15    0.774334
# 20    0.775034
# Name: mean_val_acc, dtype: float64

# %%
# Los clasificadores obtenidos con C = 1.41 reportaron la mejor
# métrica en todos los casos

# %%
# Recuperamos los ID's de las configuraciones 
results_mask = results_df['C'] == 1.41
results_df['conf_ID'][results_mask].to_list()
# Out:
# ['GQZgqx', 'hwmIFg', 'tgCmGg', 'fwZpdd', 'wavzCG']

# %%
results_df['tm_ID'][results_mask].to_list()
# Out:
# ['CgOJHi', 'bVkhBU', 'wxNaSh', 'WHTRQA', 'iTLnGg']

# %%
# Estas son las configuraciones que utilizaremos para la evaluación 
# sobre el conjunto de prueba
configurations_ids = ['GQZgqx', 'hwmIFg', 'tgCmGg', 'fwZpdd', 'wavzCG']
textmodels_ids = ['CgOJHi', 'bVkhBU', 'wxNaSh', 'WHTRQA', 'iTLnGg']

# %% [markdown]
# ### HS - sigmoid kernel

# %%
import pickle

# %%
with open('./Results/SVC/phase-4/HS_sigmoid.df', 'rb') as fh:
  results_df = pickle.load(fh)

# %%
results_df.loc[:,['conf_ID', 'tm_ID', 'C', 'mean_acc', 'mean_val_acc']]

# %%
C_mask = results_df['C']==1.41
rows2return = 'num_option', 'usr_option', 'url_option', 'hashtag_option', 'del_dup', 'delete_diac', 
results_df.loc[C_mask, 'mean_val_acc']
# Out:
# 0     0.775933
# 5     0.775000
# 10    0.775700
# 15    0.774134
# 20    0.774467
# Name: mean_val_acc, dtype: float64

# %%
# Los clasificadores obtenidos con C = 1.41 reportaron la mejor
# métrica para tres de los cinco modelos probados; y la segunda mejor
# para los restantes dos.

# %%
# Recuperamos los ID's de las configuraciones 
results_mask = results_df['C'] == 1.41
results_df['conf_ID'][results_mask].to_list()
# Out:
# ['bKgjxA', 'ddJgKe', 'qnVrDo', 'ZSDGIu', 'eJPzqU']

# %%
results_df['tm_ID'][results_mask].to_list()
# Out:
# ['fabKkA', 'pRduGU', 'SoAVcr', 'bcYlZN', 'Nilquo']

# %%
# Estas son las configuraciones que utilizaremos para la evaluación 
# sobre el conjunto de prueba
configurations_ids = ['bKgjxA', 'ddJgKe', 'qnVrDo', 'ZSDGIu', 'eJPzqU']
textmodels_ids = ['fabKkA', 'pRduGU', 'SoAVcr', 'bcYlZN', 'Nilquo']

# %%
results_df.loc[results_df.conf_ID=='eJPzqU']
# Out:
#    conf_ID   tm_ID num_option  ... mean_val_acc   mean_f1 mean_val_f1
# 20  eJPzqU  Nilquo      group  ...     0.774467  0.998354     0.75997
#
# [1 rows x 17 columns]

# %% [markdown]
# ### TR -linear kernel

# %%
with open('./Results/SVC/phase-4/TR_linear.df', 'rb') as file_handler:
  results_df = pickle.load(file_handler)

# %%
results_df.loc[:,['conf_ID', 'tm_ID', 'C', 'mean_acc', 'mean_val_acc']]

# %%
results_df.head(1)
# Out:
#   conf_ID   tm_ID num_option  ... mean_val_acc   mean_f1 mean_val_f1
# 0  GQZgqx  CgOJHi      group  ...     0.775233  0.999794    0.762061
#
# [1 rows x 17 columns]

# %%
C_mask = results_df['C']==2
rows2return = 'num_option', 'usr_option', 'url_option', 'hashtag_option', 'del_dup', 'delete_diac', 
results_df.loc[C_mask, 'mean_val_acc']
# Out:
# 1     0.878567
# 6     0.877733
# 11    0.879334
# 16    0.877533
# 21    0.879033
# Name: mean_val_acc, dtype: float64

# %%
# Recuperamos los ID's de las configuraciones 
results_mask = results_df['C'] == 2
results_df['conf_ID'][results_mask].to_list()
# Out:
# ['OFznBK', 'peKOTV', 'NnIIjU', 'PFWLCY', 'cqPNUg']

# %%
results_df['tm_ID'][results_mask].to_list()
# Out:
# ['pNqujl', 'MWagAt', 'yhmmRG', 'aiCCPb', 'qRFfIc']

# %%
# Estas son las configuraciones que utilizaremos para la evaluación 
# sobre el conjunto de prueba
configurations_ids = ['OFznBK', 'peKOTV', 'NnIIjU', 'PFWLCY', 'cqPNUg']
textmodels_ids = ['pNqujl', 'MWagAt', 'yhmmRG', 'aiCCPb', 'qRFfIc']

C=2

# %% [markdown]
# ### TR - sigmoid kernel

# %%
with open('./Results/SVC/phase-4/TR_sigmoid.df', 'rb') as file_handler:
  results_df = pickle.load(file_handler)

# %%
results_df.loc[:,['conf_ID', 'tm_ID', 'C', 'mean_acc', 'mean_val_acc']]
# Out:
#    conf_ID   tm_ID     C  mean_acc  mean_val_acc
# 0   GRFgDk  vKQhlC  1.41    0.9972      0.879200
# 1   ATGBKd  vKQhlC  2.00    0.9988      0.881400
# 2   AisnYh  vKQhlC  2.82    0.9994      0.881067
# 3   AZItei  vKQhlC  4.00    0.9998      0.880567
# 4   UobDbv  vKQhlC  5.65    0.9998      0.880333
# 5   MDdNFJ  tnRmpK  1.41    0.9966      0.878433
# 6   AjLonL  tnRmpK  2.00    0.9988      0.881033
# 7   oHvrMS  tnRmpK  2.82    0.9994      0.880033
# 8   ftituV  tnRmpK  4.00    0.9996      0.879300
# 9   ZNVglt  tnRmpK  5.65    0.9998      0.878833
# 10  ALsadY  uIjYYW  1.41    0.9976      0.879333
# 11  PDNKQY  uIjYYW  2.00    0.9988      0.882267
# 12  ujLcUP  uIjYYW  2.82    0.9994      0.881300
# 13  ZpfbJa  uIjYYW  4.00    0.9998      0.880800
# 14  DfqUHx  uIjYYW  5.65    0.9998      0.880333
# 15  mCRdwd  xzUkgN  1.41    0.9972      0.877833
# 16  ulFaFM  xzUkgN  2.00    0.9988      0.880433
# 17  vfBwub  xzUkgN  2.82    0.9994      0.880133
# ...

# %%
C_mask = results_df['C']==2
rows2return = 'num_option', 'usr_option', 'url_option', 'hashtag_option', 'del_dup', 'delete_diac', 
results_df.loc[C_mask, 'mean_val_acc']
# Out:
# 1     0.881400
# 6     0.881033
# 11    0.882267
# 16    0.880433
# 21    0.880033
# Name: mean_val_acc, dtype: float64

# %%
# Recuperamos los ID's de las configuraciones 
results_mask = results_df['C'] == 2
results_df['conf_ID'][results_mask].to_list()
# Out:
# ['ATGBKd', 'AjLonL', 'PDNKQY', 'ulFaFM', 'RVYzWK']

# %%
results_df['tm_ID'][results_mask].to_list()
# Out:
# ['vKQhlC', 'tnRmpK', 'uIjYYW', 'xzUkgN', 'rdPtoi']

# %%
# Estas son las configuraciones que utilizaremos para la evaluación 
# sobre el conjunto de prueba
configurations_ids = ['ATGBKd', 'AjLonL', 'PDNKQY', 'ulFaFM', 'RVYzWK']
textmodels_ids = ['vKQhlC', 'tnRmpK', 'uIjYYW', 'xzUkgN', 'rdPtoi']

# %%
results_df.loc[results_df.conf_ID=='PDNKQY']
# Out:
#    conf_ID   tm_ID num_option  ... mean_val_acc   mean_f1 mean_val_f1
# 11  PDNKQY  uIjYYW      group  ...     0.882267  0.998416    0.832914
#
# [1 rows x 17 columns]

# %% [markdown]
# ### AG -linear kernel

# %%
with open('./Results/SVC/phase-4/AG_linear.df', 'rb') as file_handler:
  results_df = pickle.load(file_handler)

# %%
results_df.loc[:,['conf_ID', 'tm_ID', 'C', 'mean_acc', 'mean_val_acc']]
# Out:
#    conf_ID   tm_ID     C  mean_acc  mean_val_acc
# 0   wJPAHW  JopFMW  1.41    0.9994      0.791500
# 1   Bbmvpb  JopFMW  2.00    0.9998      0.790633
# 2   IxVIvz  JopFMW  2.82    0.9998      0.790567
# 3   CCatAy  JopFMW  4.00    1.0000      0.790600
# 4   UcnhHS  JopFMW  5.65    1.0000      0.790467
# 5   ejjQUP  OqAhDb  1.41    0.9994      0.791667
# 6   PHxCSz  OqAhDb  2.00    0.9998      0.791333
# 7   lvVjPv  OqAhDb  2.82    0.9998      0.791100
# 8   hcVdOk  OqAhDb  4.00    0.9998      0.790800
# 9   cAsJNx  OqAhDb  5.65    1.0000      0.790900
# 10  ahlXxo  NflZGL  1.41    0.9994      0.790467
# 11  FFxQQF  NflZGL  2.00    0.9998      0.791067
# 12  QGMvbL  NflZGL  2.82    0.9998      0.790733
# 13  BUadTH  NflZGL  4.00    1.0000      0.790567
# 14  mYgQEz  NflZGL  5.65    1.0000      0.790633
# 15  wxHotu  lrdGCb  1.41    0.9994      0.790633
# 16  AASDFJ  lrdGCb  2.00    0.9998      0.790033
# 17  xFgJCM  lrdGCb  2.82    0.9998      0.789767
# ...

# %%
C_mask = results_df['C']==1.41
rows2return = 'num_option', 'usr_option', 'url_option', 'hashtag_option', 'del_dup', 'delete_diac', 
results_df.loc[C_mask, 'mean_val_acc']
# Out:
# 0     0.791500
# 5     0.791667
# 10    0.790467
# 15    0.790633
# 20    0.791967
# Name: mean_val_acc, dtype: float64

# %%
# Recuperamos los ID's de las configuraciones 
results_mask = results_df['C'] == 1.41
results_df['conf_ID'][results_mask].to_list()
# Out:
# ['wJPAHW', 'ejjQUP', 'ahlXxo', 'wxHotu', 'naYSFx']

# %%
results_df['tm_ID'][results_mask].to_list()
# Out:
# ['JopFMW', 'OqAhDb', 'NflZGL', 'lrdGCb', 'lQVifv']

# %%
# Estas son las configuraciones que utilizaremos para la evaluación 
# sobre el conjunto de prueba
configurations_ids = ['wJPAHW', 'ejjQUP', 'ahlXxo', 'wxHotu', 'naYSFx']
textmodels_ids = ['JopFMW', 'OqAhDb', 'NflZGL', 'lrdGCb', 'lQVifv']

C = 1.41

# %% [markdown]
# ### AG - sigmoid kernel

# %%
with open('./Results/SVC/phase-4/AG_sigmoid.df', 'rb') as file_handler:
  results_df = pickle.load(file_handler)

# %%
results_df.loc[:,['conf_ID', 'tm_ID', 'C', 'mean_acc', 'mean_val_acc']]

# %%
C_mask = results_df['C']==1.41
rows2return = 'num_option', 'usr_option', 'url_option', 'hashtag_option', 'del_dup', 'delete_diac', 
results_df.loc[C_mask, 'mean_val_acc']
# Out:
# 1     0.881400
# 6     0.881033
# 11    0.882267
# 16    0.880433
# 21    0.880033
# Name: mean_val_acc, dtype: float64

# %%
# Recuperamos los ID's de las configuraciones 
results_mask = results_df['C'] == 1.41
results_df['conf_ID'][results_mask].to_list()
# Out:
# ['cpagTE', 'jlugvH', 'GMUaEy', 'bwiAzB', 'kMJPac']

# %%
results_df['tm_ID'][results_mask].to_list()
# Out:
# ['bOsLGf', 'TCbkrJ', 'OKbEvO', 'iIVaiv', 'sJCvyU']

# %%
# Estas son las configuraciones que utilizaremos para la evaluación 
# sobre el conjunto de prueba
configurations_ids = ['cpagTE', 'jlugvH', 'GMUaEy', 'bwiAzB', 'kMJPac']
textmodels_ids = ['bOsLGf', 'TCbkrJ', 'OKbEvO', 'iIVaiv', 'sJCvyU']

C = 1.41

# %%
results_df.loc[results_df.conf_ID=='kMJPac']
# Out:
#    conf_ID   tm_ID num_option  ... mean_val_acc   mean_f1 mean_val_f1
# 20  kMJPac  sJCvyU      group  ...        0.791  0.996186    0.736618
#
# [1 rows x 17 columns]

# %% [markdown]
# ### HTA - linear kernel

# %%
import pickle

# %%
with open('./Results/SVC/phase-4/HTA_linear.df', 'rb') as fh:
  results_df = pickle.load(fh)

# %%
results_df.head()
# Out:
#   conf_ID   tm_ID num_option  ... mean_val_acc   mean_f1 mean_val_f1
# 0  HvLUwc  wKlLLQ      group  ...     0.730633  0.996360    0.399958
# 1  eKpEEc  wKlLLQ      group  ...     0.732400  0.999170    0.412866
# 2  LjcINC  wKlLLQ      group  ...     0.732067  0.999881    0.412933
# 3  QYrjWf  wKlLLQ      group  ...     0.732100  1.000000    0.412996
# 4  DpJpUD  wKlLLQ      group  ...     0.731634  1.000000    0.412726
#
# [5 rows x 17 columns]

# %%
results_df.loc[:,['conf_ID', 'tm_ID', 'C', 'mean_acc', 'mean_val_acc']]
# Out:
#    conf_ID   tm_ID     C  mean_acc  mean_val_acc
# 0   HvLUwc  wKlLLQ  1.41  0.998000      0.730633
# 1   eKpEEc  wKlLLQ  2.00  0.999000      0.732400
# 2   LjcINC  wKlLLQ  2.82  0.999800      0.732067
# 3   QYrjWf  wKlLLQ  4.00  1.000000      0.732100
# 4   DpJpUD  wKlLLQ  5.65  1.000000      0.731634
# 5   CRRESI  pTurDN  1.41  0.998200      0.725200
# 6   lFupON  pTurDN  2.00  0.999201      0.728067
# 7   CaMchL  pTurDN  2.82  0.999800      0.727867
# 8   HZhVdD  pTurDN  4.00  0.999800      0.727733
# 9   KvncHW  pTurDN  5.65  1.000000      0.727333
# 10  Rbwips  HsOAlr  1.41  0.997001      0.727367
# 11  XulowM  HsOAlr  2.00  0.998600      0.729533
# 12  fKwvjF  HsOAlr  2.82  0.999800      0.729333
# 13  tZwEKk  HsOAlr  4.00  0.999800      0.728833
# 14  LIeBzg  HsOAlr  5.65  1.000000      0.728200
# 15  vSnvFG  CmFmfJ  1.41  0.997201      0.725933
# 16  JonAxF  CmFmfJ  2.00  0.998400      0.726167
# 17  QkoUZe  CmFmfJ  2.82  0.999600      0.725300
# ...

# %%
C_mask = results_df['C']==2
rows2return = 'num_option', 'usr_option', 'url_option', 'hashtag_option', 'del_dup', 'delete_diac', 
results_df.loc[C_mask, 'mean_val_acc']
# Out:
# 1     0.732400
# 6     0.728067
# 11    0.729533
# 16    0.726167
# 21    0.729700
# Name: mean_val_acc, dtype: float64

# %%
# Los clasificadores obtenidos con C = 1.41 reportaron la mejor
# métrica para los cinco modelos de texto probados

# %%
# Recuperamos los ID's de las configuraciones 
results_mask = results_df['C'] == 2
results_df['conf_ID'][results_mask].to_list()
# Out:
# ['eKpEEc', 'lFupON', 'XulowM', 'JonAxF', 'Etgzct']

# %%
results_df['tm_ID'][results_mask].to_list()
# Out:
# ['wKlLLQ', 'pTurDN', 'HsOAlr', 'CmFmfJ', 'YXTXdt']

# %%
# Estas son las configuraciones que utilizaremos para la evaluación 
# sobre el conjunto de prueba
configurations_ids = ['eKpEEc', 'lFupON', 'XulowM', 'JonAxF', 'Etgzct']
textmodels_ids = ['wKlLLQ', 'pTurDN', 'HsOAlr', 'CmFmfJ', 'YXTXdt']

# %% [markdown]
# ### HTA - sigmoid kernel

# %%
import pickle

# %%
with open('./Results/SVC/phase-4/HTA_sigmoid.df', 'rb') as fh:
  results_df = pickle.load(fh)

# %%
results_df.head()
# Out:
#   conf_ID   tm_ID num_option  ... mean_val_acc   mean_f1 mean_val_f1
# 0  ZUPUTs  djwYeF      group  ...     0.725000  0.984347    0.359392
# 1  KAcOYq  djwYeF      group  ...     0.736766  0.997753    0.409708
# 2  Fmtcys  djwYeF      group  ...     0.735700  0.999286    0.414407
# 3  WNTYpJ  djwYeF      group  ...     0.735233  0.999644    0.414325
# 4  wxXvZo  djwYeF      group  ...     0.735100  0.999881    0.414350
#
# [5 rows x 17 columns]

# %%
results_df.loc[:,['conf_ID', 'tm_ID', 'C', 'mean_acc', 'mean_val_acc']]

# %%
C_mask = results_df['C']==2
rows2return = 'num_option', 'usr_option', 'url_option', 'hashtag_option', 'del_dup', 'delete_diac', 
results_df.loc[C_mask, 'mean_val_acc']

# %%
# Los clasificadores obtenidos con C = 2 reportaron la mejor
# métrica con cinco modelos de texto probados

# %%
# Recuperamos los ID's de las configuraciones 
results_mask = results_df['C'] == 2
results_df['conf_ID'][results_mask].to_list()
# Out:
# ['KAcOYq', 'bmCbAB', 'pcPfNL', 'wNOXbH', 'hVEaUj']

# %%
results_df['tm_ID'][results_mask].to_list()
# Out:
# ['djwYeF', 'TqHwoB', 'sUlSKy', 'CgdcXu', 'oDWZfJ']

# %%
# Estas son las configuraciones que utilizaremos para la evaluación 
# sobre el conjunto de prueba
configurations_ids = ['KAcOYq', 'bmCbAB', 'pcPfNL', 'wNOXbH', 'hVEaUj']
textmodels_ids = ['djwYeF', 'TqHwoB', 'sUlSKy', 'CgdcXu', 'oDWZfJ']

# %%
results_df.loc[results_df.conf_ID=='KAcOYq']
# Out:
#   conf_ID   tm_ID num_option  ... mean_val_acc   mean_f1 mean_val_f1
# 1  KAcOYq  djwYeF      group  ...     0.736766  0.997753    0.409708
#
# [1 rows x 17 columns]
