# %% [markdown]
# # --- CHECK COMPLETE ---

# %% [markdown]
# # Ajustes iniciales

# %% [markdown]
# ## Conexión a drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd ./drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks'

# %% [markdown]
# ## Importar los módulos *_utils

# %%
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/')
from my_utils import dataset_utils
from my_utils import eval_utils
from my_utils import nn_utils
from my_utils import results_utils

# %%
import pickle

# %% [markdown]
# # Funciones locales

# %% [markdown]
# ## Prototipos de modelo
#
# The requirements to use the cuDNN implementation are:
#
# 1. activation == tanh
# 2. recurrent_activation == sigmoid
# 3. recurrent_dropout == 0
# 4. unroll is False
# 5. use_bias is True
# 6. Inputs, if use masking, are strictly right-padded.
# 7. Eager execution is enabled in the outermost context.
#
# Check: KERAS docs [https://keras.io/api/layers/recurrent_layers/lstm/]

# %% [markdown]
# ### biLSTM

# %%
from tensorflow import keras
from tensorflow.keras import layers

def bidirectionalLSTM_NetModel(task, params, optimizer, verbose = False):
  """
  Defines and compiles a new Keras model for a Convolutional Neural Network

  """

  SEQ_LENGTH = 55
  VEC_EMBEDDINGS_DIM = 300

  units_lstm = params['units_lstm']
  merge_mode = params['merge_mode']
  units_DL1, units_DL2 = params['dense_layers_sizes']

  lstm_dropout  = params['lstm_dropout']
  dense_dropout = params['dense_dropout']


  embedding_sequences_input = keras.Input(name='INPUT',
                                          shape=(SEQ_LENGTH, VEC_EMBEDDINGS_DIM), 
                                          dtype="float64")
  
  LSTM_layer    = layers.LSTM(units=units_lstm, dropout=lstm_dropout, recurrent_dropout=0, return_sequences=False, name='LSTM')
  BiLSTM_layer  = layers.Bidirectional(LSTM_layer, merge_mode, name='BI-LSTM')

  lstm_output = BiLSTM_layer(embedding_sequences_input)
  
  fc_layer_1 = layers.Dense(units_DL1, activation="relu", name = 'DL_1')(lstm_output)
  fc_layer_1 = layers.Dropout(dense_dropout, name = 'DROP_1')(fc_layer_1)
  fc_layer_2 = layers.Dense(units_DL2, activation="relu", name = 'DL_2')(fc_layer_1)
  fc_layer_2 = layers.Dropout(dense_dropout/2, name = 'DROP_2')(fc_layer_2)

  if task in ['HS', 'TR', 'AG']:
    preds = layers.Dense(1, activation="sigmoid", name = 'PREDICTOR')(fc_layer_2)
    model = keras.Model(embedding_sequences_input, preds)

    model.compile(loss="binary_crossentropy", optimizer=optimizer, metrics=["acc"])

  elif task == 'HTA':
    preds = layers.Dense(5, activation="softmax", name = 'PREDICTOR')(fc_layer_2)
    preds = reshape = layers.Reshape(target_shape=(5,))(preds)

    model = keras.Model(embedding_sequences_input, preds)
    model.compile(loss="categorical_crossentropy", optimizer=optimizer, metrics=["acc"])

  if verbose:
    model.summary()

  return model

# %% [markdown]
# ## Dataset

# %%
X_train, Y_train = dataset_utils.loadEncodedTrainData(embedding_type='FT3',
                                                 encoding_format='EMB-SEQ',
                                                 labels_to_return=['AG'],
                                                 n_folds=7)
# Out:
# FastText 3 - Spanish Unannotated Corpora
# Encoding Format: EMB-SEQ
#
# Process complete
# 5000 train instances retrieved
#
# encodings_dim = (55, 300)

# %% [markdown]
# # Bloque 1 (optimizers)

# %% [markdown]
# ## Espacio de búsqueda

# %% [markdown]
# **Parámetros de la arquitectura**

# %%
from itertools import product

dense_layers_sizes = [(450,100),
                      (400,75)]  

arch_params = {'units_lstm':[100,200,300],
          'dense_layers_sizes': dense_layers_sizes,
          'merge_mode':['concat'],
          'lstm_dropout':[0.5],                      
          'dense_dropout':[0.5]}

arch_params_keys = arch_params.keys()

arch_params_combos = list(product( *arch_params.values() ))          

#arch_params_combos = [params_combo for params_combo in arch_params_combos if params_combo[-2]>=params_combo[-1]]
print('{} arch_params_combos.'.format(len(arch_params_combos)))
# Out:
# 6 arch_params_combos.

# %% [markdown]
# **Parámetros de la arquitectura**

# %%
trainig_params_dict = {'optimizer':['adam-1e-3', 'adam-5e-4', 'adam-1e-4', 'rmsprop-1e-3', 'rmsprop-5e-4', 'rmsprop-1e-4'],
                       'batch_size':[256,512,1024],
                       'max_epochs':[75]}
                        

training_params_keys = trainig_params_dict.keys()
trainig_params_combos = list(product( *trainig_params_dict.values() ))

print('\n{} trainig_params_combos.'.format(len(trainig_params_combos)))
# Out:
# 18 trainig_params_combos.

# %%
search_space = list(product(arch_params_combos, trainig_params_combos))

print('\n{} params combinations in the search_space.'.format(len(search_space)))
# Out:
# 108 params combinations in the search_space.

# %% [markdown]
# ## Escaneo

# %%
results_df = nn_utils.spaceScanner(X_train, Y_train,
                          'AG',
                          bidirectionalLSTM_NetModel, 
                          search_space[50:],
                          arch_params_keys,
                          training_params_keys,
                          fraction2eval=1,
                          n_folds=7,
                          fitting_attemps=1,
                          stop_threshold=1,
                          partial_CV=True,
                          backup_file='./Results/BiLSTM/AG/experiments_1.df',
                          backup_freq=5,
                          save_history_files=True,
                          save_models_as_json=False)

## mean time per run (2.5 min)

# %% [markdown]
# ## Resultados

# %%
import pickle
with open('./Results/BiLSTM/AG/experiments_1.df', 'rb') as file_handler:
  results_df = pickle.load(file_handler)

# %%
results_df.sort_values(by='val_acc_A', ascending=False).head()

# %%
results_df.sort_values(by='val_acc_B', ascending=False).head()

# %%
params_dict = {'optimizer':['adam-1e-3', 'adam-5e-4', 'adam-1e-4', 
                            'rmsprop-1e-3', 'rmsprop-5e-4', 'rmsprop-1e-4']                                
}

results_utils.plotResultsByParameter1(results_df, 
                       params_dict, 
                       params2plot=['optimizer'],
                       metric='val_acc_A')

results_utils.plotResultsByParameter1(results_df, 
                       params_dict, 
                       params2plot=['optimizer'],
                       metric='val_acc_B')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
optimizer_mask = results_df['optimizer'].isin(['adam-1e-3','adam-5e-4'])

results_utils.plotResultsByParameter1(results_df.loc[optimizer_mask], 
                       {'batch_size':[256,512,1024]}, 
                       params2plot=['batch_size'],
                       metric='val_acc_A')

results_utils.plotResultsByParameter1(results_df.loc[optimizer_mask], 
                       {'batch_size':[256,512,1024]}, 
                       params2plot=['batch_size'],
                       metric='val_acc_B')

# %%
params_dict = {'units_lstm':[100,200,300]}

results_utils.plotResultsByParameter1(results_df.loc[optimizer_mask], 
                       params_dict, 
                       params2plot=['units_lstm'],
                       metric='val_acc_A')

results_utils.plotResultsByParameter1(results_df.loc[optimizer_mask], 
                       params_dict, 
                       params2plot=['units_lstm'],
                       metric='val_acc_B')

# %% [markdown]
# ### Resumen de los resultados (checked)
#
# * lstm_units: [-100-,200]
#
# * optimizador: [**'adam-1e-3'**, 'adam-5e-4']
# * batch_size: [**256**, 1024]

# %% [markdown]
# # Bloque 2 (lstm_units + dense_layers_sizes)

# %% [markdown]
# ## Espacio de búsqueda

# %% [markdown]
# **Parámetros de la arquitectura**

# %%
from itertools import product

dense_layers_sizes = [(400,100),
                      (400,75), 
                      (300,100),
                      (300,75),
                      (200,100),
                      (200,75)]  

arch_params = {'units_lstm':[100,150,200],
          'dense_layers_sizes': dense_layers_sizes,
          'merge_mode':['concat'],
          'lstm_dropout':[0.5],                      
          'dense_dropout':[0.5]}

arch_params_keys = arch_params.keys()

arch_params_combos = list(product( *arch_params.values() ))          

#arch_params_combos = [params_combo for params_combo in arch_params_combos if params_combo[-2]>=params_combo[-1]]
print('{} arch_params_combos.'.format(len(arch_params_combos)))
# Out:
# 18 arch_params_combos.

# %% [markdown]
# **Parámetros de la arquitectura**

# %%
trainig_params_dict = {'optimizer':['adam-1e-3'],
                       'batch_size':[256, 1024],
                       'max_epochs':[75]}
                        

training_params_keys = trainig_params_dict.keys()
trainig_params_combos = list(product( *trainig_params_dict.values() ))

print('\n{} trainig_params_combos.'.format(len(trainig_params_combos)))
# Out:
# 2 trainig_params_combos.

# %%
search_space = list(product(arch_params_combos, trainig_params_combos))

print('\n{} params combinations in the search_space.'.format(len(search_space)))
# Out:
# 36 params combinations in the search_space.

# %% [markdown]
# ## Escaneo

# %%
results_df = nn_utils.spaceScanner(X_train, Y_train,
                          'AG',
                          bidirectionalLSTM_NetModel, 
                          search_space[:],
                          arch_params_keys,
                          training_params_keys,
                          fraction2eval=1,
                          n_folds=7,
                          fitting_attemps=1,
                          stop_threshold=1,
                          partial_CV=True,
                          backup_file='./Results/BiLSTM/AG/experiments_2.df',
                          backup_freq=2,
                          save_history_files=True,
                          save_models_as_json=False)

# %% [markdown]
# ## Resultados

# %%
import pickle
with open('./Results/BiLSTM/AG/experiments_2.df', 'rb') as file_handler:
  results_df = pickle.load(file_handler)

results_df.shape
# Out:
# (36, 17)

# %%
results_df.sort_values(by='val_acc_A', ascending=False).head(30)

# %%
results_df.sort_values(by='val_acc_B', ascending=False).head()

# %%
params_dict = {'units_lstm':[100,150,200]}

results_utils.plotResultsByParameter1(results_df, 
                       params_dict, 
                       params2plot=['units_lstm'],
                       metric='val_acc_A')

results_utils.plotResultsByParameter1(results_df, 
                       params_dict, 
                       params2plot=['units_lstm'],
                       metric='val_acc_B')

# %%
units_lstm_mask = results_df['units_lstm'].isin([150,200])

params_dict = {'dense_layers_sizes':[(400,100),
                      (400,75), 
                      (300,100),
                      (300,75),
                      (200,100),
                      (200,75)] }

results_utils.plotResultsByParameter1(results_df[units_lstm_mask], 
                       params_dict, 
                       params2plot=['dense_layers_sizes'],
                       metric='val_acc_A')

results_utils.plotResultsByParameter1(results_df[units_lstm_mask], 
                       params_dict, 
                       params2plot=['dense_layers_sizes'],
                       metric='val_acc_B')

# %% [markdown]
# ### Resumen de los resultados
#
# * lstm_units: [150,-200-]
# * dense_layers_sizes: [(400,75), (200,75)]
#
#
# * optimizador: [**'adam-1e-3'**, 'adam-5e-4']
# * batch-size: [-256-, 1024]

# %% [markdown]
# # Bloque 3 (dropout)

# %% [markdown]
# ## Espacio de búsqueda

# %% [markdown]
# **Parámetros de la arquitectura**

# %%
from itertools import product

# For methos A experiments
dense_layers_sizes = [(400,75),
                      (200,75)]  

arch_params = {'units_lstm':[200],
          'dense_layers_sizes': dense_layers_sizes,
          'merge_mode':['concat'],
          'lstm_dropout':[0.3,0.5,0.7],                      
          'dense_dropout':[0.3,0.5,0.7]}

arch_params_combos  = list(product( *arch_params.values() )) 
arch_params_keys = arch_params.keys()        

#arch_params_combos = [params_combo for params_combo in arch_params_combos if params_combo[-2]>=params_combo[-1]]
print('{} arch_params_combos.'.format(len(arch_params_combos)))
# Out:
# 18 arch_params_combos.

# %% [markdown]
# **Parámetros de la arquitectura**

# %%
trainig_params_dict = {'optimizer':['adam-1e-3'],
                       'batch_size':[256, 1024],
                       'max_epochs':[75]}
                        
training_params_keys = trainig_params_dict.keys()
trainig_params_combos = list(product( *trainig_params_dict.values() ))

print('\n{} trainig_params_combos.'.format(len(trainig_params_combos)))
# Out:
# 2 trainig_params_combos.

# %%
search_space = list(product(arch_params_combos, trainig_params_combos))

print('\n{} params combinations in the search_space.'.format(len(search_space)))
# Out:
# 36 params combinations in the search_space.

# %% [markdown]
# ## Escaneo

# %%
results_df = nn_utils.spaceScanner(X_train, Y_train,
                          'AG',
                          bidirectionalLSTM_NetModel, 
                          search_space[:],
                          arch_params_keys,
                          training_params_keys,
                          fraction2eval=1,
                          n_folds=7,
                          fitting_attemps=1,
                          stop_threshold=1,
                          partial_CV=True,
                          backup_file='./Results/BiLSTM/AG/experiments_3.df',
                          backup_freq=5,
                          save_history_files=True,
                          save_models_as_json=False)

# %% [markdown]
# ## Resultados

# %%
import pickle
with open('./Results/BiLSTM/AG/experiments_3.df', 'rb') as file_handler:
  results_df = pickle.load(file_handler)

results_df.shape
# Out:
# (36, 17)

# %%
results_df.sort_values(by='val_acc_A', ascending=False).head()

# %%
results_df.sort_values(by='val_acc_B', ascending=False).head()

# %%
params_dict = {'lstm_dropout':[0.3,0.5,0.7]}

results_utils.plotResultsByParameter1(results_df, 
                       params_dict, 
                       params2plot=['lstm_dropout'],
                       metric='val_acc_A')

results_utils.plotResultsByParameter1(results_df, 
                       params_dict, 
                       params2plot=['lstm_dropout'],
                       metric='val_acc_B')

# %%
lstm_drop_mask = results_df.lstm_dropout==0.7

params_dict = {'dense_dropout':[0.3,0.5,0.7]}

results_utils.plotResultsByParameter1(results_df.loc[lstm_drop_mask], 
                       params_dict, 
                       params2plot=['dense_dropout'],
                       metric='val_acc_A')

results_utils.plotResultsByParameter1(results_df.loc[lstm_drop_mask], 
                       params_dict, 
                       params2plot=['dense_dropout'],
                       metric='val_acc_B')

# %%
params_dict = {'batch_size':[256,1024]}  

results_utils.plotResultsByParameter1(results_df.loc[lstm_drop_mask], 
                       params_dict, 
                       params2plot=['batch_size'],
                       metric='val_acc_A')

results_utils.plotResultsByParameter1(results_df.loc[lstm_drop_mask], 
                       params_dict, 
                       params2plot=['batch_size'],
                       metric='val_acc_B')

# %% [markdown]
# ### Resumen de los resultados (checked)
#
# * lstm_units: 150, -200-
# * dense_layers_sizes: [(400,75), (200,75)]
# * lstm_dropout: 0.7
# * dense dropout: [0.3, 0.5]
#
#
# * optimizador: [**'adam-1e-3'**, 'adam-5e-4']
# * batch_size [-256-,1024]

# %% [markdown]
# # Bloque 4 (validación completa)

# %% [markdown]
# ### Espacio de búsqueda

# %% [markdown]
# **Parámetros de la arquitectura**

# %%
from itertools import product

# For methos A experiments
dense_layers_sizes = [(400,75),
                      (200,75)]  

arch_params = {'units_lstm':[150,200],
          'dense_layers_sizes': dense_layers_sizes,
          'merge_mode':['concat'],
          'lstm_dropout':[0.7],                      
          'dense_dropout':[0.3,0.5]}

arch_params_combos  = list(product( *arch_params.values() )) 
arch_params_keys = arch_params.keys()        

#arch_params_combos = [params_combo for params_combo in arch_params_combos if params_combo[-2]>=params_combo[-1]]
print('{} arch_params_combos.'.format(len(arch_params_combos)))
# Out:
# 8 arch_params_combos.

# %% [markdown]
# **Parámetros de la arquitectura**

# %%
trainig_params_dict = {'optimizer':['adam-1e-3'],
                       'batch_size':[256, 1024],
                       'max_epochs':[75]}
                        
training_params_keys = trainig_params_dict.keys()
trainig_params_combos = list(product( *trainig_params_dict.values() ))

print('\n{} trainig_params_combos.'.format(len(trainig_params_combos)))
# Out:
# 2 trainig_params_combos.

# %%
search_space = list(product(arch_params_combos, trainig_params_combos))

print('\n{} params combinations in the search_space.'.format(len(search_space)))
# Out:
# 16 params combinations in the search_space.

# %% [markdown]
# ## Escaneo

# %%
results_df = nn_utils.spaceScanner(X_train, Y_train,
                          'AG',
                          bidirectionalLSTM_NetModel, 
                          search_space[:],
                          arch_params_keys,
                          training_params_keys,
                          fraction2eval=1,
                          n_folds=7,
                          fitting_attemps=1,
                          stop_threshold=1,
                          partial_CV=False,
                          backup_file='./Results/BiLSTM/AG/experiments_4f.df',
                          backup_freq=1,
                          save_history_files=True,
                          save_models_as_json=True,
                          save_weights=True)
# Out:
# BackupFile: ./Results/BiLSTM/AG/experiments_4f.df
# SCANNING SEARCH SPACE
#
# 16 configurations will be evaluated.
# 1  - conf_ID: jNbUqAaM   *******  --  train_acc_1 = 0.806,  val_acc_1 = 0.81     --  train_acc_2 = 0.804,  val_acc_2 = 0.82
# 2  - conf_ID: GQeWbWQq   *******  --  train_acc_1 = 0.834,  val_acc_1 = 0.81     --  train_acc_2 = 0.806,  val_acc_2 = 0.822
# 3  - conf_ID: QkHWDSeg   *******  --  train_acc_1 = 0.835,  val_acc_1 = 0.814    --  train_acc_2 = 0.816,  val_acc_2 = 0.823
# 4  - conf_ID: haUlGPxu   *******  --  train_acc_1 = 0.79,   val_acc_1 = 0.814    --  train_acc_2 = 0.805,  val_acc_2 = 0.828
# 5  - conf_ID: KdbeXmEX   *******  --  train_acc_1 = 0.788,  val_acc_1 = 0.813    --  train_acc_2 = 0.815,  val_acc_2 = 0.823
# 6  - conf_ID: xadMTvrj   *******  --  train_acc_1 = 0.791,  val_acc_1 = 0.814    --  train_acc_2 = 0.808,  val_acc_2 = 0.824
# 7  - conf_ID: VXXZXjPY   *******  --  train_acc_1 = 0.814,  val_acc_1 = 0.815    --  train_acc_2 = 0.815,  val_acc_2 = 0.826
# 8  - conf_ID: tOYuufHH   *******  --  train_acc_1 = 0.821,  val_acc_1 = 0.815    --  train_acc_2 = 0.791,  val_acc_2 = 0.827
# 9  - conf_ID: nNGNupAr   *******  --  train_acc_1 = 0.826,  val_acc_1 = 0.81     --  train_acc_2 = 0.809,  val_acc_2 = 0.819
# 10 - conf_ID: GyODlyQA   *******  --  train_acc_1 = 0.819,  val_acc_1 = 0.812    --  train_acc_2 = 0.817,  val_acc_2 = 0.824
# 11 - conf_ID: BUTpSihx   *******  --  train_acc_1 = 0.797,  val_acc_1 = 0.817    --  train_acc_2 = 0.806,  val_acc_2 = 0.829
# 12 - conf_ID: LsAblDhn   *******  --  train_acc_1 = 0.806,  val_acc_1 = 0.813    --  train_acc_2 = 0.808,  val_acc_2 = 0.822
# 13 - conf_ID: NAZvEZFC   *******  --  train_acc_1 = 0.801,  val_acc_1 = 0.812    --  train_acc_2 = 0.816,  val_acc_2 = 0.823
# 14 - conf_ID: lbHWGNYx   *******  --  train_acc_1 = 0.787,  val_acc_1 = 0.811    --  train_acc_2 = 0.806,  val_acc_2 = 0.82
# 15 - conf_ID: Afxwglds   *******  --  train_acc_1 = 0.8,    val_acc_1 = 0.816    --  train_acc_2 = 0.798,  val_acc_2 = 0.825
# 16 - conf_ID: bTfvBAtk   *******  --  train_acc_1 = 0.819,  val_acc_1 = 0.813    --  train_acc_2 = 0.802,  val_acc_2 = 0.821
#
# PROCCESS COMPLETE. 16 CONFIGURATIONS WERE SUCCESFULLY EVALUATED.

# %% [markdown]
# ## Resultados

# %%
import pickle
from pandas import DataFrame

with open('./Results/BiLSTM/AG/experiments_4f.df', 'rb') as file_handler:
  search_results = pickle.load(file_handler)

search_results.shape
# Out:
# (16, 17)
