# %% [markdown]
# # Link notebook to google drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive/Colab Notebooks
# Out:
# /content/gdrive/My Drive/Colab Notebooks

# %% [markdown]
# # Import preprocessed Tweets from drive

# %%
import pickle
with open('dataset_files/PreprocessedTrainTweets_pr2', 'rb') as filehandle:
    # store the encoded documents as binary data
    train_tweets = pickle.load(filehandle)

with open('dataset_files/PreprocessedTestTweets_pr2', 'rb') as filehandle:
    # store the encoded documents as binary data
    test_tweets = pickle.load(filehandle)

# %%
train_tweets[0], test_tweets[0]
# Out:
# (['easyjet',
#   'quiere',
#   'duplicar',
#   'el',
#   'número',
#   'de',
#   'mujeres',
#   'piloto',
#   'verás',
#   'tú',
#   'para',
#   'aparcar',
#   'el',
#   'avión',
#   'enlace'],
#  ['me',
#   'estoy',
#   'comiendo',
#   'la',
#   'picada',
#   'árabe',
#   'más',
#   'rica',
#   'de',
#   'mi',
#   'vida'])

# %%
from gensim.models.fasttext import FastText

# %%
model = FastText(size=100, window=2, min_count=3, sorted_vocab=1)  # instantiate
model.build_vocab(sentences=train_tweets)
model.train(sentences=train_tweets, total_examples=len(train_tweets), epochs=50)

# %%
model.wv.vocab
# Out:
# {'quiere': <gensim.models.keyedvectors.Vocab at 0x7fa0fa844dd8>,
#  'duplicar': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8449b0>,
#  'el': <gensim.models.keyedvectors.Vocab at 0x7fa0fa844630>,
#  'número': <gensim.models.keyedvectors.Vocab at 0x7fa0fa844fd0>,
#  'de': <gensim.models.keyedvectors.Vocab at 0x7fa1029c2048>,
#  'mujeres': <gensim.models.keyedvectors.Vocab at 0x7fa112ac0208>,
#  'verás': <gensim.models.keyedvectors.Vocab at 0x7fa102a5c940>,
#  'tú': <gensim.models.keyedvectors.Vocab at 0x7fa102a5c048>,
#  'para': <gensim.models.keyedvectors.Vocab at 0x7fa102a5ce80>,
#  'avión': <gensim.models.keyedvectors.Vocab at 0x7fa102a5c320>,
#  'enlace': <gensim.models.keyedvectors.Vocab at 0x7fa102a5c780>,
#  'gobierno': <gensim.models.keyedvectors.Vocab at 0x7fa102a5cba8>,
#  'debe': <gensim.models.keyedvectors.Vocab at 0x7fa102a5ce48>,
#  'crear': <gensim.models.keyedvectors.Vocab at 0x7fa102a5ccc0>,
#  'un': <gensim.models.keyedvectors.Vocab at 0x7fa102a5c6a0>,
#  'control': <gensim.models.keyedvectors.Vocab at 0x7fa102a5c9e8>,
#  'inmigración': <gensim.models.keyedvectors.Vocab at 0x7fa102a5c7f0>,
#  'en': <gensim.models.keyedvectors.Vocab at 0x7fa102a5cd30>,
#  'las': <gensim.models.keyedvectors.Vocab at 0x7fa102a5c080>,
#  'con': <gensim.models.keyedvectors.Vocab at 0x7fa102a5cf98>,
#  'colombia': <gensim.models.keyedvectors.Vocab at 0x7fa102a5ceb8>,
#  'por': <gensim.models.keyedvectors.Vocab at 0x7fa102a5c2b0>,
#  'q': <gensim.models.keyedvectors.Vocab at 0x7fa102a5c828>,
#  'después': <gensim.models.keyedvectors.Vocab at 0x7fa102a5c8d0>,
#  'del': <gensim.models.keyedvectors.Vocab at 0x7fa102a5c898>,
#  'venir': <gensim.models.keyedvectors.Vocab at 0x7fa102a5c588>,
#  'masa': <gensim.models.keyedvectors.Vocab at 0x7fa102a5cb00>,
#  'yo': <gensim.models.keyedvectors.Vocab at 0x7fa102a5ccf8>,
#  'veo': <gensim.models.keyedvectors.Vocab at 0x7fa102a5cf60>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x7fa0fa82ed68>,
#  'acoso': <gensim.models.keyedvectors.Vocab at 0x7fa0fa82e438>,
#  'laboral': <gensim.models.keyedvectors.Vocab at 0x7fa0fa82e9b0>,
#  'y': <gensim.models.keyedvectors.Vocab at 0x7fa0fa82ea58>,
#  'callejero': <gensim.models.keyedvectors.Vocab at 0x7fa0fa82e7f0>,
#  'otras': <gensim.models.keyedvectors.Vocab at 0x7fa0fa82e898>,
#  'depresión': <gensim.models.keyedvectors.Vocab at 0x7fa0fa82e978>,
#  'violación': <gensim.models.keyedvectors.Vocab at 0x7fa0fa82ee48>,
#  'sexual': <gensim.models.keyedvectors.Vocab at 0x7fa0fa82e2e8>,
#  'o': <gensim.models.keyedvectors.Vocab at 0x7fa0fa82eba8>,
#  'maltrato': <gensim.models.keyedvectors.Vocab at 0x7fa0fa82eef0>,
#  'varias': <gensim.models.keyedvectors.Vocab at 0x7fa0fa82eda0>,
#  'que': <gensim.models.keyedvectors.Vocab at 0x7fa0fa82e9e8>,
#  'se': <gensim.models.keyedvectors.Vocab at 0x7fa102b50e10>,
#  'este': <gensim.models.keyedvectors.Vocab at 0x7fa102b50b70>,
#  'tipo': <gensim.models.keyedvectors.Vocab at 0x7fa102b50ba8>,
#  'machistas': <gensim.models.keyedvectors.Vocab at 0x7fa102b501d0>,
#  'vas': <gensim.models.keyedvectors.Vocab at 0x7fa102b50ef0>,
#  'seguir': <gensim.models.keyedvectors.Vocab at 0x7fa102b50e80>,
#  'tu': <gensim.models.keyedvectors.Vocab at 0x7fa102b508d0>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x7fa102b50f28>,
#  'pobre': <gensim.models.keyedvectors.Vocab at 0x7fa102b50828>,
#  '?': <gensim.models.keyedvectors.Vocab at 0x7fa102b50b38>,
#  'soy': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820dd8>,
#  'los': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820470>,
#  'demás': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820da0>,
#  'les': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820b38>,
#  'recuerdo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820b70>,
#  'lo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8201d0>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8209e8>,
#  'si': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820f60>,
#  'escoria': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820860>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820e10>,
#  'es': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820400>,
#  'culpa': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8200f0>,
#  'mía': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820390>,
#  'claro': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8202e8>,
#  'sé': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820320>,
#  '!': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8209b0>,
#  'quién': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820be0>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820d68>,
#  'tomas': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820518>,
#  'antonio': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820630>,
#  'caballero': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820e48>,
#  'como': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820cc0>,
#  'ser': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820a58>,
#  'mal': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820828>,
#  'gusto': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8207f0>,
#  'e': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820d30>,
#  'la': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820a90>,
#  'vez': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820f28>,
#  'mismo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820358>,
#  'pero': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820898>,
#  'hay': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8202b0>,
#  'violencia': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820b00>,
#  'nombre': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820278>,
#  'hijo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8206a0>,
#  'puta': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8208d0>,
#  'sobra': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8207b8>,
#  'mundo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820ac8>,
#  'pablo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820710>,
#  'casado': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820240>,
#  'debería': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820780>,
#  'estudiar': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820080>,
#  'máster': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8204a8>,
#  'vos': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820908>,
#  'haces': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820588>,
#  'eso': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820748>,
#  'te': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820eb8>,
#  'pego': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8204e0>,
#  'una': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8206d8>,
#  'patada': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820048>,
#  'cara': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8200b8>,
#  'tema': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820668>,
#  'detienen': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820128>,
#  'nacional': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8205c0>,
#  'haitiano': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820978>,
#  'indocumentado': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820a20>,
#  'llora': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820198>,
#  'mereces': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820fd0>,
#  'zorra': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8203c8>,
#  'padres': <gensim.models.keyedvectors.Vocab at 0x7fa0fa820208>,
#  'indocumentados': <gensim.models.keyedvectors.Vocab at 0x7fa104dbe4a8>,
#  'hambre': <gensim.models.keyedvectors.Vocab at 0x7fa104dbe470>,
#  'pedir': <gensim.models.keyedvectors.Vocab at 0x7fa104dbe320>,
#  'porque': <gensim.models.keyedvectors.Vocab at 0x7fa104dbe3c8>,
#  'personas': <gensim.models.keyedvectors.Vocab at 0x7fa104dbe390>,
#  'piensan': <gensim.models.keyedvectors.Vocab at 0x7fa104dbe780>,
#  'todos': <gensim.models.keyedvectors.Vocab at 0x7fa102aa8898>,
#  'inmigrantes': <gensim.models.keyedvectors.Vocab at 0x7fa102aa88d0>,
#  'delincuentes': <gensim.models.keyedvectors.Vocab at 0x7fa102aa82b0>,
#  'cállate': <gensim.models.keyedvectors.Vocab at 0x7fa102aa8d68>,
#  'estoy': <gensim.models.keyedvectors.Vocab at 0x7fa102aa8c88>,
#  'callate': <gensim.models.keyedvectors.Vocab at 0x7fa12c3edbe0>,
#  'quieras': <gensim.models.keyedvectors.Vocab at 0x7fa112ab3ac8>,
#  'culo': <gensim.models.keyedvectors.Vocab at 0x7fa104bfcd68>,
#  'risa': <gensim.models.keyedvectors.Vocab at 0x7fa104bfcac8>,
#  'casi': <gensim.models.keyedvectors.Vocab at 0x7fa104bfc588>,
#  'al': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a048>,
#  'estilo': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a080>,
#  'gabacho': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a0b8>,
#  'presidente': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a0f0>,
#  'lujo': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a128>,
#  'perú': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a160>,
#  'va': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a198>,
#  'mundial': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a1d0>,
#  'juez': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a208>,
#  'cita': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a240>,
#  'menor': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a278>,
#  'abusos': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a2b0>,
#  'parte': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a2e8>,
#  'jugadores': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a320>,
#  'madre': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a358>,
#  'merecía': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a390>,
#  'tanto': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a3c8>,
#  'haber': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a400>,
#  'pasado': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a438>,
#  'tantos': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a470>,
#  'pd': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a4a8>,
#  'ver': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a4e0>,
#  'tv': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a518>,
#  'todavía': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a550>,
#  'qué': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a588>,
#  'servicio': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a5c0>,
#  'público': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a5f8>,
#  'ofrece': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a630>,
#  'merezca': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a668>,
#  'dinero': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a6a0>,
#  'nuestros': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a6d8>,
#  'impuestos': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a710>,
#  'solo': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a748>,
#  'hace': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a780>,
#  'daño': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a7b8>,
#  'unos': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a7f0>,
#  'estaba': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a828>,
#  'esta': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a860>,
#  'vida': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a898>,
#  'inmigrante': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a8d0>,
#  'iba': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a908>,
#  'difícil': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a940>,
#  'verdad': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a978>,
#  'mira': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a9b0>,
#  'vd': <gensim.models.keyedvectors.Vocab at 0x7fa104c8a9e8>,
#  'hasta': <gensim.models.keyedvectors.Vocab at 0x7fa104c8aa20>,
#  'polla': <gensim.models.keyedvectors.Vocab at 0x7fa104c8aa58>,
#  'ya': <gensim.models.keyedvectors.Vocab at 0x7fa104c8aa90>,
#  'más': <gensim.models.keyedvectors.Vocab at 0x7fa104c8aac8>,
#  'tonterías': <gensim.models.keyedvectors.Vocab at 0x7fa104c8ab00>,
#  'tienes': <gensim.models.keyedvectors.Vocab at 0x7fa104c8ab38>,
#  'ni': <gensim.models.keyedvectors.Vocab at 0x7fa104c8ab70>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x7fa104c8aba8>,
#  'mi': <gensim.models.keyedvectors.Vocab at 0x7fa104c8abe0>,
#  'novia': <gensim.models.keyedvectors.Vocab at 0x7fa104c8ac50>,
#  'sevillista': <gensim.models.keyedvectors.Vocab at 0x7fa104c8acf8>,
#  'mas': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5630>,
#  'niño': <gensim.models.keyedvectors.Vocab at 0x7fa102aa55c0>,
#  'han': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5710>,
#  'neta': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5748>,
#  'estar': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5780>,
#  'contra': <gensim.models.keyedvectors.Vocab at 0x7fa102aa57b8>,
#  'trabajo': <gensim.models.keyedvectors.Vocab at 0x7fa102aa57f0>,
#  'cualquier': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5828>,
#  'cosa': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5860>,
#  'víctimas': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5898>,
#  'mierdas': <gensim.models.keyedvectors.Vocab at 0x7fa102aa58d0>,
#  'dedican': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5908>,
#  'violar': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5940>,
#  'uno': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5978>,
#  'tambien': <gensim.models.keyedvectors.Vocab at 0x7fa102aa59b0>,
#  'metido': <gensim.models.keyedvectors.Vocab at 0x7fa102aa59e8>,
#  'hacer': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5a20>,
#  'nos': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5a58>,
#  'gusta': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5a90>,
#  'hagan': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5ac8>,
#  'odio': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5b00>,
#  'viejos': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5b38>,
#  'creen': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5b70>,
#  'merecen': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5ba8>,
#  'todo': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5be0>,
#  'eres': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5c18>,
#  'demasiado': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5c50>,
#  'perra': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5c88>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5cc0>,
#  'boca': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5cf8>,
#  'gordo': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5d30>,
#  'gran': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5d68>,
#  'regalo': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5da0>,
#  'aquí': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5dd8>,
#  'le': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5e10>,
#  'regalado': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5e48>,
#  'nada': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5e80>,
#  'ha': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5eb8>,
#  'muchísimo': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5ef0>,
#  'vale': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5f28>,
#  'final': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5f60>,
#  'hija': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5f98>,
#  'unas': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5fd0>,
#  'cancha': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5668>,
#  'también': <gensim.models.keyedvectors.Vocab at 0x7fa102aa56a0>,
#  'somos': <gensim.models.keyedvectors.Vocab at 0x7fa102aa56d8>,
#  'desde': <gensim.models.keyedvectors.Vocab at 0x7fa102aa55f8>,
#  'él': <gensim.models.keyedvectors.Vocab at 0x7fa102aa5518>,
#  'verdadera': <gensim.models.keyedvectors.Vocab at 0x7fa104cbe518>,
#  'cagada': <gensim.models.keyedvectors.Vocab at 0x7fa104cbe208>,
#  'puto': <gensim.models.keyedvectors.Vocab at 0x7fa104cbe1d0>,
#  'mierda': <gensim.models.keyedvectors.Vocab at 0x7fa104cbe198>,
#  'entre': <gensim.models.keyedvectors.Vocab at 0x7fa104cbe160>,
#  'putos': <gensim.models.keyedvectors.Vocab at 0x7fa104cbe128>,
#  'sudakas': <gensim.models.keyedvectors.Vocab at 0x7fa104cbe0f0>,
#  'miserables': <gensim.models.keyedvectors.Vocab at 0x7fa104cbe0b8>,
#  'sorete': <gensim.models.keyedvectors.Vocab at 0x7fa104cbe080>,
#  'parido': <gensim.models.keyedvectors.Vocab at 0x7fa104cbe048>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x7fa104cbe240>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849438>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8497f0>,
#  'g': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8490b8>,
#  'ero': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849ba8>,
#  'asi': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849898>,
#  'digo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8494e0>,
#  'mami': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849908>,
#  'ven': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849470>,
#  'joder': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849400>,
#  'hostia': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849a90>,
#  'dos': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8499e8>,
#  'amigos': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849c88>,
#  'hablando': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8493c8>,
#  'raúl': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849eb8>,
#  'das': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849588>,
#  'mujer': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849cf8>,
#  'trato': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849e10>,
#  'hecho': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8492e8>,
#  're': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849668>,
#  'digan': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849710>,
#  'aunque': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849f98>,
#  'seas': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849ef0>,
#  'negro': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849550>,
#  'noche': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849518>,
#  'ah': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849828>,
#  'vaina': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849208>,
#  'ahora': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849978>,
#  'puedo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849cc0>,
#  'criticar': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849d30>,
#  'dios': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849748>,
#  'mío': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849240>,
#  'gente': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849be0>,
#  'así': <gensim.models.keyedvectors.Vocab at 0x7fa104c48be0>,
#  'invasion': <gensim.models.keyedvectors.Vocab at 0x7fa104c48160>,
#  'entrada': <gensim.models.keyedvectors.Vocab at 0x7fa104c48da0>,
#  'masiva': <gensim.models.keyedvectors.Vocab at 0x7fa104c48748>,
#  'subsaharianos': <gensim.models.keyedvectors.Vocab at 0x7fa104c48f28>,
#  'ceuta': <gensim.models.keyedvectors.Vocab at 0x7fa104c48cf8>,
#  'españa': <gensim.models.keyedvectors.Vocab at 0x7fa104c48278>,
#  'via': <gensim.models.keyedvectors.Vocab at 0x7fa104c48588>,
#  'par': <gensim.models.keyedvectors.Vocab at 0x7fa104c484a8>,
#  'esto': <gensim.models.keyedvectors.Vocab at 0x7fa104c48048>,
#  'estás': <gensim.models.keyedvectors.Vocab at 0x7fa104c48ef0>,
#  'preguntas': <gensim.models.keyedvectors.Vocab at 0x7fa104c48b38>,
#  'callada': <gensim.models.keyedvectors.Vocab at 0x7fa104c48b70>,
#  'está': <gensim.models.keyedvectors.Vocab at 0x7fa104c48898>,
#  'miras': <gensim.models.keyedvectors.Vocab at 0x7fa104c482b0>,
#  'hacia': <gensim.models.keyedvectors.Vocab at 0x7fa104c487b8>,
#  'atrás': <gensim.models.keyedvectors.Vocab at 0x7fa104c48668>,
#  'encuentras': <gensim.models.keyedvectors.Vocab at 0x7fa104c485c0>,
#  'ese': <gensim.models.keyedvectors.Vocab at 0x7fa104c48d68>,
#  'deben': <gensim.models.keyedvectors.Vocab at 0x7fa104c48940>,
#  'segundo': <gensim.models.keyedvectors.Vocab at 0x7fa104c48390>,
#  'árabes': <gensim.models.keyedvectors.Vocab at 0x7fa104c482e8>,
#  'chinos': <gensim.models.keyedvectors.Vocab at 0x7fa104c48cc0>,
#  'tienen': <gensim.models.keyedvectors.Vocab at 0x7fa104c487f0>,
#  'jodidos': <gensim.models.keyedvectors.Vocab at 0x7fa104c48080>,
#  'vienen': <gensim.models.keyedvectors.Vocab at 0x7fa104c48f98>,
#  'sus': <gensim.models.keyedvectors.Vocab at 0x7fa104c48a90>,
#  'países': <gensim.models.keyedvectors.Vocab at 0x7fa104c48dd8>,
#  'mano': <gensim.models.keyedvectors.Vocab at 0x7fa104c48908>,
#  'delante': <gensim.models.keyedvectors.Vocab at 0x7fa104c48198>,
#  'consiguen': <gensim.models.keyedvectors.Vocab at 0x7fa104c48e10>,
#  'negocios': <gensim.models.keyedvectors.Vocab at 0x7fa104c489e8>,
#  'venezolano': <gensim.models.keyedvectors.Vocab at 0x7fa104c48128>,
#  'acá': <gensim.models.keyedvectors.Vocab at 0x7fa104c48a20>,
#  've': <gensim.models.keyedvectors.Vocab at 0x7fa104c48400>,
#  'mucho': <gensim.models.keyedvectors.Vocab at 0x7fa104c488d0>,
#  'esa': <gensim.models.keyedvectors.Vocab at 0x7fa104c483c8>,
#  'querida': <gensim.models.keyedvectors.Vocab at 0x7fa104c48e48>,
#  'sin': <gensim.models.keyedvectors.Vocab at 0x7fa104c48ac8>,
#  'dicen': <gensim.models.keyedvectors.Vocab at 0x7fa104c48828>,
#  'tus': <gensim.models.keyedvectors.Vocab at 0x7fa104c48438>,
#  'hijos': <gensim.models.keyedvectors.Vocab at 0x7fa104c489b0>,
#  'nuevo': <gensim.models.keyedvectors.Vocab at 0x7fa104c485f8>,
#  'amor': <gensim.models.keyedvectors.Vocab at 0x7fa104c48a58>,
#  'sigues': <gensim.models.keyedvectors.Vocab at 0x7fa104c48710>,
#  'siendo': <gensim.models.keyedvectors.Vocab at 0x7fa104c486a0>,
#  'su': <gensim.models.keyedvectors.Vocab at 0x7fa104c48c50>,
#  'ejemplo': <gensim.models.keyedvectors.Vocab at 0x7fa104c48c18>,
#  'mil': <gensim.models.keyedvectors.Vocab at 0x7fa104c48208>,
#  'atender': <gensim.models.keyedvectors.Vocab at 0x7fa104c48eb8>,
#  'refugiados': <gensim.models.keyedvectors.Vocab at 0x7fa104c48d30>,
#  'venezolanos': <gensim.models.keyedvectors.Vocab at 0x7fa104c48860>,
#  'cómo': <gensim.models.keyedvectors.Vocab at 0x7fa104c48470>,
#  'cuando': <gensim.models.keyedvectors.Vocab at 0x7fa104c48f60>,
#  'bien': <gensim.models.keyedvectors.Vocab at 0x7fa104c484e0>,
#  'era': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828fd0>,
#  'perras': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828f98>,
#  'intentan': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828f60>,
#  'escondidos': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828f28>,
#  'vía': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828ef0>,
#  'maldito': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828eb8>,
#  'fue': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828e80>,
#  'pueblo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828e48>,
#  'merecia': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828e10>,
#  'pinche': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828dd8>,
#  'navidad': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828da0>,
#  'paga': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828d68>,
#  'factura': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828d30>,
#  'dejar': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828cf8>,
#  'ilegales': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828cc0>,
#  'sueltos': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828c88>,
#  'ciudades': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828c50>,
#  'votantes': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828c18>,
#  'pagar': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828be0>,
#  'dentro': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828ba8>,
#  'año': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828b70>,
#  'tiempo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828b38>,
#  'existe': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828b00>,
#  'espacio': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828ac8>,
#  'hombre': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828a90>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828a58>,
#  'respeto': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828a20>,
#  'decir': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8289e8>,
#  'fin': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8289b0>,
#  'fregar': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828978>,
#  'mandan': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828940>,
#  'cultura': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828908>,
#  'mejores': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8288d0>,
#  'puede': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828898>,
#  'algo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828860>,
#  'asesinos': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828828>,
#  'conferencia': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8287f0>,
#  'hora': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8287b8>,
#  'primera': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828780>,
#  'llegado': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828748>,
#  'patera': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828710>,
#  'costas': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8286d8>,
#  'ciudadanos': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8286a0>,
#  'tonto': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828668>,
#  'pruebas': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828630>,
#  'donde': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8285f8>,
#  'estabas': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8285c0>,
#  'habia': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828588>,
#  'sudaca': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828550>,
#  'vuelta': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828518>,
#  'super': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8284e0>,
#  'estas': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8284a8>,
#  'concha': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828470>,
#  'congreso': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828438>,
#  'primaria': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828400>,
#  'hagas': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8283c8>,
#  'santa': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828390>,
#  'cuarta': <gensim.models.keyedvectors.Vocab at 0x7fa104c48550>,
#  'metes': <gensim.models.keyedvectors.Vocab at 0x7fa104c48358>,
#  'pack': <gensim.models.keyedvectors.Vocab at 0x7fa0fa849e80>,
#  'meten': <gensim.models.keyedvectors.Vocab at 0x7fa0fa844d68>,
#  'ponen': <gensim.models.keyedvectors.Vocab at 0x7fa102a5c9b0>,
#  'cuello': <gensim.models.keyedvectors.Vocab at 0x7fa102a5c748>,
#  'corre': <gensim.models.keyedvectors.Vocab at 0x7fa102a5c860>,
#  'coño': <gensim.models.keyedvectors.Vocab at 0x7fa104cbe780>,
#  'estáis': <gensim.models.keyedvectors.Vocab at 0x7fa104cbe940>,
#  'alguien': <gensim.models.keyedvectors.Vocab at 0x7fa104cbec50>,
#  'arabe': <gensim.models.keyedvectors.Vocab at 0x7fa104cbe908>,
#  'ay': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828358>,
#  'maldad': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828320>,
#  'voy': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8282e8>,
#  'aqui': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8282b0>,
#  'aprende': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828278>,
#  'hablar': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828240>,
#  'hocico': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828208>,
#  'sobre': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8281d0>,
#  'racismo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828198>,
#  'alemania': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828160>,
#  'alemán': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828128>,
#  'pinches': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8280f0>,
#  'ves': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8280b8>,
#  'algún': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828080>,
#  'día': <gensim.models.keyedvectors.Vocab at 0x7fa0fa828048>,
#  'gilipollas': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823048>,
#  'vuestra': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823080>,
#  'mueves': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8230b8>,
#  'lento': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8230f0>,
#  'siento': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823128>,
#  'recorrido': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823160>,
#  'presión': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823198>,
#  'pecho': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8231d0>,
#  'sientes': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823208>,
#  'nena': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823240>,
#  'país': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823278>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8232b0>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8232e8>,
#  'pensiones': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823320>,
#  'robar': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823358>,
#  'sistema': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823390>,
#  'judicial': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8233c8>,
#  'sanitario': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823400>,
#  'importa': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823438>,
#  'dice': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823470>,
#  'libertad': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8234a8>,
#  'cabeza': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8234e0>,
#  'comemela': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823518>,
#  'xddd': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823550>,
#  'peor': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823588>,
#  'luego': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8235c0>,
#  'estos': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8235f8>,
#  'simios': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823630>,
#  'fondo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823668>,
#  'lastima': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8236a0>,
#  'seres': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8236d8>,
#  'humana': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823710>,
#  'lacra': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823748>,
#  'asquerosa': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823780>,
#  'moromierda': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8237b8>,
#  'musulmono': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8237f0>,
#  'viva': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823828>,
#  'carajo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823860>,
#  'entiendo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823898>,
#  'enseñarle': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8238d0>,
#  'cualquiera': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823908>,
#  'encuentro': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823940>,
#  'sentido': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823978>,
#  'tragar': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8239b0>,
#  'acuerdo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa8239e8>,
#  'ningún': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823a20>,
#  'subir': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823a58>,
#  'fotos': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823a90>,
#  'desnuda': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823ac8>,
#  'venezuela': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823b00>,
#  'encima': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823b38>,
#  'chavista': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823b70>,
#  'malparido': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823ba8>,
#  'valen': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823be0>,
#  'años': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823c18>,
#  'palo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823c50>,
#  'pasando': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823c88>,
#  'ahorita': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823cc0>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823cf8>,
#  'ido': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823d30>,
#  'hablado': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823d68>,
#  'árabe': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823da0>,
#  'justo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823dd8>,
#  'l': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823e10>,
#  'dia': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823e48>,
#  'siguiente': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823e80>,
#  'documental': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823eb8>,
#  'cierto': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823ef0>,
#  'excelente': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823f28>,
#  'realidad': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823f60>,
#  'diciendo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823f98>,
#  'ellos': <gensim.models.keyedvectors.Vocab at 0x7fa0fa823fd0>,
#  'fueron': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a048>,
#  'provocar': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a080>,
#  'podes': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a0b8>,
#  'tan': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a0f0>,
#  'peña': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a128>,
#  'loca': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a160>,
#  'meterte': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a198>,
#  'sacar': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a1d0>,
#  'alcohol': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a208>,
#  'inteligentes': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a240>,
#  'hombres': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a278>,
#  'cambio': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a2b0>,
#  'sexo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a2e8>,
#  'revés': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a320>,
#  'latinos': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a358>,
#  'sudacas': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a390>,
#  'cosas': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a3c8>,
#  'pintar': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a400>,
#  'pelo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a438>,
#  'quiera': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a470>,
#  'muestran': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a4a8>,
#  'violenta': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a4e0>,
#  'peleas': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a518>,
#  'plena': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a550>,
#  'calle': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a588>,
#  'ayer': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a5c0>,
#  'muriendo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a5f8>,
#  'garganta': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a630>,
#  'hoy': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a668>,
#  'mejor': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a6a0>,
#  'amiga': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a6d8>,
#  'espaldas': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a710>,
#  'ella': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a748>,
#  'estupida': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a780>,
#  'cago': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a7b8>,
#  'robo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a7f0>,
#  'raoul': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a828>,
#  'ganado': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a860>,
#  'sido': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a898>,
#  'muy': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a8d0>,
#  'piensa': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a908>,
#  'próxima': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a940>,
#  'dan': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a978>,
#  'otra': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a9b0>,
#  'mayor': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81a9e8>,
#  'comiendo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81aa20>,
#  'vamos': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81aa58>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81aa90>,
#  'besos': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81aac8>,
#  'pa': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81ab00>,
#  'feliz': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81ab38>,
#  'viernes': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81ab70>,
#  'instagram': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81aba8>,
#  'twitter': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81abe0>,
#  'ridículas': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81ac18>,
#  'facebook': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81ac50>,
#  'whatsapp': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81ac88>,
#  'misma': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81acc0>,
#  'historias': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81acf8>,
#  'resentido': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81ad30>,
#  'busquen': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81ad68>,
#  'queremos': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81ada0>,
#  'desnudo': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81add8>,
#  'siempre': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81ae10>,
#  'arte': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81ae48>,
#  'animal': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81ae80>,
#  'sos': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81aeb8>,
#  'merecés': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81aef0>,
#  'vivir': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81af28>,
#  'manera': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81af60>,
#  'merecias': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81af98>,
#  'adán': <gensim.models.keyedvectors.Vocab at 0x7fa0fa81afd0>,
#  'sevilla': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb048>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb080>,
#  'hago': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb0b8>,
#  'aguante': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb0f0>,
#  'menores': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb128>,
#  'futuro': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb160>,
#  'juego': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb198>,
#  'mañana': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb1d0>,
#  'quieren': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb208>,
#  'trabajar': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb240>,
#  'esos': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb278>,
#  'papeles': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb2b0>,
#  'irregulares': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb2e8>,
#  'buenos': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb320>,
#  'dias': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb358>,
#  'gracias': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb390>,
#  'sánchez': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb3c8>,
#  'algunas': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb400>,
#  'feministas': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb438>,
#  'vestido': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb470>,
#  'ojo': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb4a8>,
#  'ahí': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb4e0>,
#  'muchos': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb518>,
#  'sí': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb550>,
#  'respuesta': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb588>,
#  'likes': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb5c0>,
#  'ostia': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb5f8>,
#  'llamar': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb630>,
#  'mala': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb668>,
#  'verdadero': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb6a0>,
#  'asco': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb6d8>,
#  'leer': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb710>,
#  'ataques': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb748>,
#  'diario': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb780>,
#  'medios': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb7b8>,
#  'pro': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb7f0>,
#  'independentistas': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb828>,
#  'necesitamos': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb860>,
#  'nunca': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb898>,
#  'demuestra': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb8d0>,
#  'guerra': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb908>,
#  'sino': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb940>,
#  'humano': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb978>,
#  'cuenta': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb9b0>,
#  'mentiras': <gensim.models.keyedvectors.Vocab at 0x7fa104bdb9e8>,
#  'busca': <gensim.models.keyedvectors.Vocab at 0x7fa104bdba20>,
#  'invadir': <gensim.models.keyedvectors.Vocab at 0x7fa104bdba58>,
#  'jugando': <gensim.models.keyedvectors.Vocab at 0x7fa104bdba90>,
#  'enseñaron': <gensim.models.keyedvectors.Vocab at 0x7fa104bdbac8>,
#  'bastante': <gensim.models.keyedvectors.Vocab at 0x7fa104bdbb00>,
#  'remil': <gensim.models.keyedvectors.Vocab at 0x7fa104bdbb38>,
#  'llevamos': <gensim.models.keyedvectors.Vocab at 0x7fa104bdbb70>,
#  'casos': <gensim.models.keyedvectors.Vocab at 0x7fa104bdbba8>,
#  'zona': <gensim.models.keyedvectors.Vocab at 0x7fa104bdbbe0>,
#  'barcelona': <gensim.models.keyedvectors.Vocab at 0x7fa104bdbc18>,
#  'semana': <gensim.models.keyedvectors.Vocab at 0x7fa104bdbc50>,
#  'partir': <gensim.models.keyedvectors.Vocab at 0x7fa104bdbc88>,
#  'cuantos': <gensim.models.keyedvectors.Vocab at 0x7fa104bdbcc0>,
#  'dejan': <gensim.models.keyedvectors.Vocab at 0x7fa104bdbcf8>,
#  'tanga': <gensim.models.keyedvectors.Vocab at 0x7fa104bdbd30>,
#  'lado': <gensim.models.keyedvectors.Vocab at 0x7fa104bdbd68>,
#  'dejas': <gensim.models.keyedvectors.Vocab at 0x7fa104bdbda0>,
#  'caer': <gensim.models.keyedvectors.Vocab at 0x7fa104bdbdd8>,
#  'despacio': <gensim.models.keyedvectors.Vocab at 0x7fa104bdbe10>,
#  'placer': <gensim.models.keyedvectors.Vocab at 0x7fa104bdbe48>,
#  'da': <gensim.models.keyedvectors.Vocab at 0x7fa104bdbe80>,
#  'sentir': <gensim.models.keyedvectors.Vocab at 0x7fa104bdbeb8>,
#  'aprieta': <gensim.models.keyedvectors.Vocab at 0x7fa104bdbef0>,
#  'durante': <gensim.models.keyedvectors.Vocab at 0x7fa104bdbf28>,
#  'baja': <gensim.models.keyedvectors.Vocab at 0x7fa104bdbf60>,
#  'quiero': <gensim.models.keyedvectors.Vocab at 0x7fa104bdbf98>,
#  'acaban': <gensim.models.keyedvectors.Vocab at 0x7fa104bdbfd0>,
#  'enseñar': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9048>,
#  'unico': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9080>,
#  'tener': <gensim.models.keyedvectors.Vocab at 0x7fa104bd90b8>,
#  'grande': <gensim.models.keyedvectors.Vocab at 0x7fa104bd90f0>,
#  'razón': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9128>,
#  'costumbres': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9160>,
#  'acabo': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9198>,
#  'señora': <gensim.models.keyedvectors.Vocab at 0x7fa104bd91d0>,
#  'dije': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9208>,
#  'nomas': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9240>,
#  'dijo': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9278>,
#  'x': <gensim.models.keyedvectors.Vocab at 0x7fa104bd92b0>,
#  'único': <gensim.models.keyedvectors.Vocab at 0x7fa104bd92e8>,
#  'publicidad': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9320>,
#  'tacos': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9358>,
#  'camino': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9390>,
#  'viejo': <gensim.models.keyedvectors.Vocab at 0x7fa104bd93c8>,
#  'lt': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9400>,
#  'deje': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9438>,
#  'policía': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9470>,
#  'niñas': <gensim.models.keyedvectors.Vocab at 0x7fa104bd94a8>,
#  'pobres': <gensim.models.keyedvectors.Vocab at 0x7fa104bd94e0>,
#  'vete': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9518>,
#  'tomar': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9550>,
#  'felipe': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9588>,
#  'mina': <gensim.models.keyedvectors.Vocab at 0x7fa104bd95c0>,
#  'sigue': <gensim.models.keyedvectors.Vocab at 0x7fa104bd95f8>,
#  'estando': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9630>,
#  'solamente': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9668>,
#  'basura': <gensim.models.keyedvectors.Vocab at 0x7fa104bd96a0>,
#  'persona': <gensim.models.keyedvectors.Vocab at 0x7fa104bd96d8>,
#  'cual': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9710>,
#  'sorprende': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9748>,
#  'orto': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9780>,
#  'amigo': <gensim.models.keyedvectors.Vocab at 0x7fa104bd97b8>,
#  'irte': <gensim.models.keyedvectors.Vocab at 0x7fa104bd97f0>,
#  'ocurre': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9828>,
#  'ambos': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9860>,
#  'lados': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9898>,
#  'valla': <gensim.models.keyedvectors.Vocab at 0x7fa104bd98d0>,
#  'toda': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9908>,
#  'gustaría': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9940>,
#  'oficina': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9978>,
#  'atención': <gensim.models.keyedvectors.Vocab at 0x7fa104bd99b0>,
#  'prieto': <gensim.models.keyedvectors.Vocab at 0x7fa104bd99e8>,
#  'atendemos': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9a20>,
#  'primero': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9a58>,
#  'pase': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9a90>,
#  'simio': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9ac8>,
#  'tengo': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9b00>,
#  'menudo': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9b38>,
#  'tío': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9b70>,
#  'espero': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9ba8>,
#  'vaya': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9be0>,
#  'puerta': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9c18>,
#  'vemos': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9c50>,
#  'voz': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9c88>,
#  'eh': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9cc0>,
#  'movimiento': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9cf8>,
#  'semen': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9d30>,
#  'pone': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9d68>,
#  'verte': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9da0>,
#  'cielo': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9dd8>,
#  'quedes': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9e10>,
#  'sola': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9e48>,
#  'manteros': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9e80>,
#  'saltaron': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9eb8>,
#  'otro': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9ef0>,
#  'pedimos': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9f28>,
#  'palabras': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9f60>,
#  'corazón': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9f98>,
#  'calles': <gensim.models.keyedvectors.Vocab at 0x7fa104bd9fd0>,
#  'pesao': <gensim.models.keyedvectors.Vocab at 0x7fa104bda048>,
#  'pide': <gensim.models.keyedvectors.Vocab at 0x7fa104bda080>,
#  'disculpas': <gensim.models.keyedvectors.Vocab at 0x7fa104bda0b8>,
#  'lucas': <gensim.models.keyedvectors.Vocab at 0x7fa104bda0f0>,
#  'dm': <gensim.models.keyedvectors.Vocab at 0x7fa104bda128>,
#  'pario': <gensim.models.keyedvectors.Vocab at 0x7fa104bda160>,
#  'ahre': <gensim.models.keyedvectors.Vocab at 0x7fa104bda198>,
#  'eras': <gensim.models.keyedvectors.Vocab at 0x7fa104bda1d0>,
#  'meses': <gensim.models.keyedvectors.Vocab at 0x7fa104bda208>,
#  'querés': <gensim.models.keyedvectors.Vocab at 0x7fa104bda240>,
#  'tocado': <gensim.models.keyedvectors.Vocab at 0x7fa104bda278>,
#  'libro': <gensim.models.keyedvectors.Vocab at 0x7fa104bda2b0>,
#  'historia': <gensim.models.keyedvectors.Vocab at 0x7fa104bda2e8>,
#  'saber': <gensim.models.keyedvectors.Vocab at 0x7fa104bda320>,
#  'hablas': <gensim.models.keyedvectors.Vocab at 0x7fa104bda358>,
#  'podría': <gensim.models.keyedvectors.Vocab at 0x7fa104bda390>,
#  'explicar': <gensim.models.keyedvectors.Vocab at 0x7fa104bda3c8>,
#  'subsahariano': <gensim.models.keyedvectors.Vocab at 0x7fa104bda400>,
#  'habrá': <gensim.models.keyedvectors.Vocab at 0x7fa104bda438>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x7fa104bda470>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x7fa104bda4a8>,
#  'darte': <gensim.models.keyedvectors.Vocab at 0x7fa104bda4e0>,
#  'ricas': <gensim.models.keyedvectors.Vocab at 0x7fa104bda518>,
#  'mí': <gensim.models.keyedvectors.Vocab at 0x7fa104bda550>,
#  'encantaría': <gensim.models.keyedvectors.Vocab at 0x7fa104bda588>,
#  'pegarte': <gensim.models.keyedvectors.Vocab at 0x7fa104bda5c0>,
#  'porno': <gensim.models.keyedvectors.Vocab at 0x7fa104bda5f8>,
#  'van': <gensim.models.keyedvectors.Vocab at 0x7fa104bda630>,
#  'andan': <gensim.models.keyedvectors.Vocab at 0x7fa104bda668>,
#  'llamando': <gensim.models.keyedvectors.Vocab at 0x7fa104bda6a0>,
#  'gata': <gensim.models.keyedvectors.Vocab at 0x7fa104bda6d8>,
#  'manga': <gensim.models.keyedvectors.Vocab at 0x7fa104bda710>,
#  'ridiculas': <gensim.models.keyedvectors.Vocab at 0x7fa104bda748>,
#  'tamales': <gensim.models.keyedvectors.Vocab at 0x7fa104bda780>,
#  'sirvienta': <gensim.models.keyedvectors.Vocab at 0x7fa104bda7b8>,
#  'salir': <gensim.models.keyedvectors.Vocab at 0x7fa104bda7f0>,
#  'bueno': <gensim.models.keyedvectors.Vocab at 0x7fa104bda828>,
#  'cuento': <gensim.models.keyedvectors.Vocab at 0x7fa104bda860>,
#  'ustedes': <gensim.models.keyedvectors.Vocab at 0x7fa104bda898>,
#  'universidad': <gensim.models.keyedvectors.Vocab at 0x7fa104bda8d0>,
#  'insultando': <gensim.models.keyedvectors.Vocab at 0x7fa104bda908>,
#  'asesino': <gensim.models.keyedvectors.Vocab at 0x7fa104bda940>,
#  'diana': <gensim.models.keyedvectors.Vocab at 0x7fa104bda978>,
# ...
#  'habrán': <gensim.models.keyedvectors.Vocab at 0x7fa104bdac88>,
#  'venga': <gensim.models.keyedvectors.Vocab at 0x7fa104bdacc0>,
#  'dicho': <gensim.models.keyedvectors.Vocab at 0x7fa104bdacf8>,
#  'ingles': <gensim.models.keyedvectors.Vocab at 0x7fa104bdad30>,
#  'mica': <gensim.models.keyedvectors.Vocab at 0x7fa104bdad68>,
#  'imbécil': <gensim.models.keyedvectors.Vocab at 0x7fa104bdada0>,
#  'putas': <gensim.models.keyedvectors.Vocab at 0x7fa104bdadd8>,
#  'cuales': <gensim.models.keyedvectors.Vocab at 0x7fa104bdae10>,
#  'españoles': <gensim.models.keyedvectors.Vocab at 0x7fa104bdae48>,
#  'negros': <gensim.models.keyedvectors.Vocab at 0x7fa104bdae80>,
#  'visto': <gensim.models.keyedvectors.Vocab at 0x7fa104bdaeb8>,
#  'poniendo': <gensim.models.keyedvectors.Vocab at 0x7fa104bdaef0>,
#  'pies': <gensim.models.keyedvectors.Vocab at 0x7fa104bdaf28>,
#  'dormir': <gensim.models.keyedvectors.Vocab at 0x7fa104bdaf60>,
#  'están': <gensim.models.keyedvectors.Vocab at 0x7fa104bdaf98>,
#  'ayudar': <gensim.models.keyedvectors.Vocab at 0x7fa104bdafd0>,
#  'moromierdas': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4048>,
#  'llegan': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4080>,
#  'todas': <gensim.models.keyedvectors.Vocab at 0x7fa104bd40b8>,
#  'niños': <gensim.models.keyedvectors.Vocab at 0x7fa104bd40f0>,
#  'puedan': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4128>,
#  'oye': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4160>,
#  'problema': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4198>,
#  'pasa': <gensim.models.keyedvectors.Vocab at 0x7fa104bd41d0>,
#  'nietos': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4208>,
#  'director': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4240>,
#  'general': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4278>,
#  'guardia': <gensim.models.keyedvectors.Vocab at 0x7fa104bd42b0>,
#  'civil': <gensim.models.keyedvectors.Vocab at 0x7fa104bd42e8>,
#  'tarde': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4320>,
#  'buenas': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4358>,
#  'horas': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4390>,
#  'verdes': <gensim.models.keyedvectors.Vocab at 0x7fa104bd43c8>,
#  'recuerda': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4400>,
#  'cerda': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4438>,
#  'luchar': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4470>,
#  'gracia': <gensim.models.keyedvectors.Vocab at 0x7fa104bd44a8>,
#  'nazi': <gensim.models.keyedvectors.Vocab at 0x7fa104bd44e0>,
#  'malo': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4518>,
#  'acosos': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4550>,
#  'simple': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4588>,
#  'abuso': <gensim.models.keyedvectors.Vocab at 0x7fa104bd45c0>,
#  'delito': <gensim.models.keyedvectors.Vocab at 0x7fa104bd45f8>,
#  'coqueteo': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4630>,
#  'insistente': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4668>,
#  'torpe': <gensim.models.keyedvectors.Vocab at 0x7fa104bd46a0>,
#  'agresión': <gensim.models.keyedvectors.Vocab at 0x7fa104bd46d8>,
#  'machista': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4710>,
#  'ice': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4748>,
#  'prioridad': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4780>,
#  'lucha': <gensim.models.keyedvectors.Vocab at 0x7fa104bd47b8>,
#  'ilegal': <gensim.models.keyedvectors.Vocab at 0x7fa104bd47f0>,
#  'extranjeros': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4828>,
#  'antecedentes': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4860>,
#  'amenaza': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4898>,
#  'seguridad': <gensim.models.keyedvectors.Vocab at 0x7fa104bd48d0>,
#  'pública': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4908>,
#  'queria': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4940>,
#  'feminista': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4978>,
#  'victima': <gensim.models.keyedvectors.Vocab at 0x7fa104bd49b0>,
#  'habla': <gensim.models.keyedvectors.Vocab at 0x7fa104bd49e8>,
#  'algun': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4a20>,
#  'violacion': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4a58>,
#  'complicado': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4a90>,
#  'ex': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4ac8>,
#  's': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4b00>,
#  'regreso': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4b38>,
#  'américa': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4b70>,
#  'vs': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4ba8>,
#  'hermanos': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4be0>,
#  'momentos': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4c18>,
#  'hermano': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4c50>,
#  'ahi': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4c88>,
#  't': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4cc0>,
#  'hablo': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4cf8>,
#  'paliza': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4d30>,
#  'turista': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4d68>,
#  'americano': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4da0>,
#  'entran': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4dd8>,
#  'cal': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4e10>,
#  'franco': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4e48>,
#  'llega': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4e80>,
#  'lomito': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4eb8>,
#  'com': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4ef0>,
#  'salsa': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4f28>,
#  'discursos': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4f60>,
#  'acusados': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4f98>,
#  'sea': <gensim.models.keyedvectors.Vocab at 0x7fa104bd4fd0>,
#  'deportado': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8048>,
#  'ayudas': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8080>,
#  'antes': <gensim.models.keyedvectors.Vocab at 0x7fa104bd80b8>,
#  'propios': <gensim.models.keyedvectors.Vocab at 0x7fa104bd80f0>,
#  'cartagena': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8128>,
#  'nosotros': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8160>,
#  'depende': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8198>,
#  'dar': <gensim.models.keyedvectors.Vocab at 0x7fa104bd81d0>,
#  'solución': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8208>,
#  'paso': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8240>,
#  'invasión': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8278>,
#  'regla': <gensim.models.keyedvectors.Vocab at 0x7fa104bd82b0>,
#  'nuestras': <gensim.models.keyedvectors.Vocab at 0x7fa104bd82e8>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8320>,
#  'chica': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8358>,
#  'chistes': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8390>,
#  'rubén': <gensim.models.keyedvectors.Vocab at 0x7fa104bd83c8>,
#  'algunos': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8400>,
#  'fans': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8438>,
#  'queda': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8470>,
#  'sabe': <gensim.models.keyedvectors.Vocab at 0x7fa104bd84a8>,
#  'puro': <gensim.models.keyedvectors.Vocab at 0x7fa104bd84e0>,
#  'lindo': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8518>,
#  'sepa': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8550>,
#  'queja': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8588>,
#  'esque': <gensim.models.keyedvectors.Vocab at 0x7fa104bd85c0>,
#  'des': <gensim.models.keyedvectors.Vocab at 0x7fa104bd85f8>,
#  'asesinato': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8630>,
#  'imbeciles': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8668>,
#  'hacen': <gensim.models.keyedvectors.Vocab at 0x7fa104bd86a0>,
#  'quieran': <gensim.models.keyedvectors.Vocab at 0x7fa104bd86d8>,
#  'metro': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8710>,
#  'manejar': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8748>,
#  'política': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8780>,
#  'económica': <gensim.models.keyedvectors.Vocab at 0x7fa104bd87b8>,
#  'chávez': <gensim.models.keyedvectors.Vocab at 0x7fa104bd87f0>,
#  'había': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8828>,
#  'tenemos': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8860>,
#  'resultado': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8898>,
#  'pendeja': <gensim.models.keyedvectors.Vocab at 0x7fa104bd88d0>,
#  'común': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8908>,
#  'bajo': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8940>,
#  'vago': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8978>,
#  'humanitaria': <gensim.models.keyedvectors.Vocab at 0x7fa104bd89b0>,
#  'lleva': <gensim.models.keyedvectors.Vocab at 0x7fa104bd89e8>,
#  'agua': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8a20>,
#  'cruzan': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8a58>,
#  'desierto': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8a90>,
#  'ir': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8ac8>,
#  'contrario': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8b00>,
#  'religión': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8b38>,
#  'creencias': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8b70>,
#  'espera': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8ba8>,
#  'merecian': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8be0>,
#  'juntos': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8c18>,
#  'romper': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8c50>,
#  'reino': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8c88>,
#  'unido': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8cc0>,
#  'cero': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8cf8>,
#  'cristianos': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8d30>,
#  'sirios': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8d68>,
#  'pais': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8da0>,
#  'favor': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8dd8>,
#  'gómez': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8e10>,
#  'insulto': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8e48>,
#  'violador': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8e80>,
#  'sólo': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8eb8>,
#  'nosotras': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8ef0>,
#  'machismo': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8f28>,
#  'cultural': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8f60>,
#  'racista': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8f98>,
#  'silencio': <gensim.models.keyedvectors.Vocab at 0x7fa104bd8fd0>,
#  'chico': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2048>,
#  'padre': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2080>,
#  'denuncias': <gensim.models.keyedvectors.Vocab at 0x7fa104bd20b8>,
#  'género': <gensim.models.keyedvectors.Vocab at 0x7fa104bd20f0>,
#  'órdenes': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2128>,
#  'puso': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2160>,
#  'jamás': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2198>,
#  'pasó': <gensim.models.keyedvectors.Vocab at 0x7fa104bd21d0>,
#  'empieza': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2208>,
#  'industria': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2240>,
#  'magnate': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2278>,
#  'acusado': <gensim.models.keyedvectors.Vocab at 0x7fa104bd22b0>,
#  'haciendo': <gensim.models.keyedvectors.Vocab at 0x7fa104bd22e8>,
#  'check': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2320>,
#  'emiratos': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2358>,
#  'pensando': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2390>,
#  'significado': <gensim.models.keyedvectors.Vocab at 0x7fa104bd23c8>,
#  'quería': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2400>,
#  'palabra': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2438>,
#  'inglés': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2470>,
#  'canción': <gensim.models.keyedvectors.Vocab at 0x7fa104bd24a8>,
#  'deja': <gensim.models.keyedvectors.Vocab at 0x7fa104bd24e0>,
#  'provocarme': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2518>,
#  'maldita': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2550>,
#  'cojones': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2588>,
#  'tonta': <gensim.models.keyedvectors.Vocab at 0x7fa104bd25c0>,
#  'cárcel': <gensim.models.keyedvectors.Vocab at 0x7fa104bd25f8>,
#  'llorar': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2630>,
#  'nariz': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2668>,
#  'pregunta': <gensim.models.keyedvectors.Vocab at 0x7fa104bd26a0>,
#  'izquierda': <gensim.models.keyedvectors.Vocab at 0x7fa104bd26d8>,
#  'nota': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2710>,
#  'fronteras': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2748>,
#  'agrede': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2780>,
#  'relación': <gensim.models.keyedvectors.Vocab at 0x7fa104bd27b8>,
#  'inteligente': <gensim.models.keyedvectors.Vocab at 0x7fa104bd27f0>,
#  'vieja': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2828>,
#  'existen': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2860>,
#  'imbecil': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2898>,
#  'nadie': <gensim.models.keyedvectors.Vocab at 0x7fa104bd28d0>,
#  'bolas': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2908>,
#  'muerto': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2940>,
#  'bebé': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2978>,
#  'podrías': <gensim.models.keyedvectors.Vocab at 0x7fa104bd29b0>,
#  'enseñarme': <gensim.models.keyedvectors.Vocab at 0x7fa104bd29e8>,
#  'poco': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2a20>,
#  'educación': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2a58>,
#  'aprender': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2a90>,
#  'violan': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2ac8>,
#  'pollas': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2b00>,
#  'temon': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2b38>,
#  'estudiante': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2b70>,
#  'impide': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2ba8>,
#  'deportación': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2be0>,
#  'viene': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2c18>,
#  'áfrica': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2c50>,
#  'sitio': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2c88>,
#  'recoger': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2cc0>,
#  'africana': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2cf8>,
#  'borracha': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2d30>,
#  'hola': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2d68>,
#  'mitad': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2da0>,
#  'franchute': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2dd8>,
#  'latino': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2e10>,
#  'gt': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2e48>,
#  'm': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2e80>,
#  'mio': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2eb8>,
#  'falsa': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2ef0>,
#  'portada': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2f28>,
#  'revista': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2f60>,
#  'inventarse': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2f98>,
#  'pudo': <gensim.models.keyedvectors.Vocab at 0x7fa104bd2fd0>,
#  'ante': <gensim.models.keyedvectors.Vocab at 0x7fa102acd048>,
#  'totalmente': <gensim.models.keyedvectors.Vocab at 0x7fa102acd080>,
#  'nuestro': <gensim.models.keyedvectors.Vocab at 0x7fa102acd0b8>,
#  'buscando': <gensim.models.keyedvectors.Vocab at 0x7fa102acd0f0>,
#  'poder': <gensim.models.keyedvectors.Vocab at 0x7fa102acd128>,
#  'aquarius': <gensim.models.keyedvectors.Vocab at 0x7fa102acd160>,
#  'animales': <gensim.models.keyedvectors.Vocab at 0x7fa102acd198>,
#  'racistas': <gensim.models.keyedvectors.Vocab at 0x7fa102acd1d0>,
#  'otros': <gensim.models.keyedvectors.Vocab at 0x7fa102acd208>,
#  'africanos': <gensim.models.keyedvectors.Vocab at 0x7fa102acd240>,
#  'solucionar': <gensim.models.keyedvectors.Vocab at 0x7fa102acd278>,
#  'mafias': <gensim.models.keyedvectors.Vocab at 0x7fa102acd2b0>,
#  ...}

# %%
vocab_list =[]
for w in model.wv.vocab:
  vocab_list.append(w)

# %%
vocab_list[2]
# Out:
# 'el'

# %%
# Defining values for parameters
embedding_size = 300
window_size = 5
min_word = 10
down_sampling = 1e-2
 
# %time
fast_Text_model = FastText(train_tweets,
                           size=embedding_size,
                           window=window_size,
                           min_count=min_word,
                           sample=down_sampling,
                           workers = 4,
                           sg=1,
                           iter=50)
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.87 µs

# %%
words = model.wv.most_similar(positive=['todo'],topn=5)
words
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('modo', 0.688302755355835),
#  ('top', 0.6672989130020142),
#  ('miedo', 0.6213207244873047),
#  ('do', 0.617906928062439),
#  ('pedo', 0.6161102056503296)]

# %% [markdown]
# ## Model construction

# %%
# returns a dictionary of words and the corresponding embeddings
def glove_model(d = 300):
    import numpy as np
    print("Loading GloVe model")

    path = 'Embeddings/Pretrained_Embeddings/GloVe_1/glove.6B.{}d.txt'.format(d)

    with open(path,'r', encoding='utf8') as reader:
        #words_count = 0
        words_list = []
        embeddings_dict = {}
        for line in reader:
            w, *v = line.rstrip(' \n').split(' ')
            words_list.append(w) 
            embeddings_dict[w] = np.array(list(map(float, v)))
            #words_count += 1
      
    print("OK => ",len(embeddings_dict)," palabras")
    return (words_list, embeddings_dict)

# %%
w_list, model = glove_model(d = 300)
# Out:
# Loading GloVe model
# OK =>  400001  palabras

# %%
model['hola'].shape
# Out:
# (300,)

# %% [markdown]
# # Encoding

# %%
def tweet_encoding_bow(preprocessed_tweet, d = 300):
  import numpy as np
  encoded_tweet = np.zeros((d,))

  for w in preprocessed_tweet:
    if w in model.keys():
      encoded_tweet = encoded_tweet + model[w]

  return encoded_tweet.reshape(1,-1)

# %%
embeddings_dim = model['hola'].shape[0]
encoded_train_tweets = []
encoded_test_tweets = []

for i, tweet in enumerate(train_tweets):
  encoded_train_tweets.append(tweet_encoding_bow(tweet, d = embeddings_dim))

for i, tweet in enumerate(test_tweets):
  encoded_test_tweets.append(tweet_encoding_bow(tweet, d = embeddings_dim))

encoded_train_tweets[0].shape, encoded_test_tweets[0].shape
# Out:
# ((1, 100), (1, 100))

# %% [markdown]
# # Save encoded tweets

# %%
# save encoded tweets into disk
import pickle

embeddings_dim = model['hola'].shape[0]
encoded_train_tweets_path = 'dataset_files/EncodedTrainTweets_GloVe{}d_pr2'.format(embeddings_dim)
encoded_test_tweets_path = 'dataset_files/EncodedTestTweets_GloVe{}d_pr2'.format(embeddings_dim)

with open(encoded_train_tweets_path, 'wb') as filehandle:
    # store the encoded documents as binary data
    pickle.dump(encoded_train_tweets, filehandle)

with open(encoded_test_tweets_path, 'wb') as filehandle:
    # store the encoded documents as binary data
    pickle.dump(encoded_test_tweets, filehandle)
