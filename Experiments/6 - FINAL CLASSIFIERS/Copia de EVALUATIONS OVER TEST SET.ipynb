# %% [markdown]
# # Ajustes iniciales

# %% [markdown]
# ## Conexión a google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd ./drive/MyDrive/Colab Notebooks/
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks'

# %% [markdown]
# ## Importar modulos *_utils

# %%
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/')

from my_utils import eval_utils
from my_utils import nn_utils
from my_utils import dataset_utils
from my_utils import results_utils
import numpy as np

# %% [markdown]
# ## HS

# %%
results_list = ['./Results/final/SNN-1_HS_TEST.df',
                './Results/final/SNN-2_HS_TEST.df']

results_df = results_utils.mergeDataFrames(results_list, '.delete_this.df')  

type_mask = results_df.model_type=='G'
results_df.loc[type_mask].sort_values(by='f1-macro', ascending=False).head()
# Out:
#      conf_id model_type architecture       acc      prec    recall  f1-macro
# 37  IYwHpkvM          G        SNN-1  0.728125  0.720030  0.712653  0.715188
# 67  WTzJBbAA          G        SNN-2  0.719375  0.711455  0.714233  0.712524
# 27  ItNgrhRR          G        SNN-1  0.718750  0.709628  0.706254  0.707633
# 47  gobIDbBH          G        SNN-1  0.716875  0.709531  0.696534  0.699856
# 7   IMsHTOqQ          G        SNN-1  0.708125  0.699137  0.699919  0.699504

# %%
results_list = ['./Results/final/SNN-1_HS_VALIDATION.df',
                './Results/final/SNN-2_HS_VALIDATION.df']

results_df = results_utils.mergeDataFrames(results_list, '.delete_this.df')  


results_df.loc[results_df.conf_id=='lCVfvbZP'].mean(axis=0)
# Out:
# acc         0.790597
# prec        0.795309
# recall      0.771763
# f1-macro    0.777010
# dtype: float64

# %% [markdown]
# ## AG

# %%
results_list = ['./Results/final/SNN-1_AG_TEST.df',
                './Results/final/SNN-2_AG_TEST.df']

results_df = results_utils.mergeDataFrames(results_list, '.delete_this.df')  

type_mask = results_df.model_type=='G'
results_df.loc[type_mask].sort_values(by='f1-macro', ascending=False).head()
# Out:
#      conf_id model_type architecture       acc      prec    recall  f1-macro
# 77  xihWJsJc          G        SNN-2  0.798750  0.776795  0.710423  0.729398
# 47  heNMIfuo          G        SNN-1  0.784375  0.753517  0.694102  0.710806
# 27  oQJeIVmv          G        SNN-1  0.771875  0.727476  0.698659  0.709156
# 87  EjViPwKn          G        SNN-2  0.786250  0.766965  0.683829  0.702753
# 67  ZVAuhkHI          G        SNN-2  0.748125  0.698430  0.700109  0.699250

# %%
results_list = ['./Results/final/SNN-1_AG_VALIDATION.df',
                './Results/final/SNN-2_AG_VALIDATION.df']

results_df = results_utils.mergeDataFrames(results_list, '.delete_this.df')  


results_df.loc[results_df.conf_id=='xihWJsJc'].mean(axis=0)
# Out:
# conf_id        NaN
# model_type     NaN
# architecture   NaN
# acc            NaN
# prec           NaN
# recall         NaN
# f1-macro       NaN
# dtype: float64

# %%
results_df
# Out:
#      conf_id model_type architecture       acc      prec    recall  f1-macro
# 0   WSUJpwQP          F        SNN-1  0.798601  0.795307  0.736075  0.752348
# 1   WSUJpwQP          F        SNN-1  0.808392  0.803624  0.751689  0.767452
# 2   WSUJpwQP          F        SNN-1  0.789916  0.778399  0.731725  0.745601
# 3   WSUJpwQP          F        SNN-1  0.808123  0.797568  0.757780  0.771147
# 4   WSUJpwQP          F        SNN-1  0.778711  0.754478  0.733900  0.741788
# ..       ...        ...          ...       ...       ...       ...       ...
# 65  KjzkpEMA          F        SNN-2  0.795518  0.791201  0.732859  0.748768
# 66  KjzkpEMA          F        SNN-2  0.798319  0.785282  0.746282  0.759130
# 67  KjzkpEMA          F        SNN-2  0.792717  0.773059  0.746505  0.756303
# 68  KjzkpEMA          F        SNN-2  0.798319  0.793495  0.736164  0.752210
# 69  KjzkpEMA          F        SNN-2  0.812325  0.791437  0.782542  0.786577
#
# [70 rows x 7 columns]

# %% [markdown]
# ## TR

# %%
results_list = ['./Results/final/SNN-1_TR_TEST.df',
                './Results/final/SNN-2_TR_TEST.df']

results_df = results_utils.mergeDataFrames(results_list, '.delete_this.df')  

type_mask = results_df.model_type=='G'
results_df.loc[type_mask].sort_values(by='f1-macro', ascending=False).head()
# Out:
#      conf_id model_type architecture       acc      prec    recall  f1-macro
# 87  jawgqxcm          G        SNN-2  0.843750  0.827201  0.747654  0.773743
# 7   JVEIHntQ          G        SNN-1  0.843750  0.851242  0.729480  0.761927
# 57  wppcsrma          G        SNN-2  0.843125  0.857328  0.724512  0.757985
# 37  jsiehraH          G        SNN-1  0.840000  0.855883  0.717845  0.751164
# 17  jawgqxcm          G        SNN-1  0.833750  0.845554  0.708296  0.740234

# %%
results_list = ['./Results/final/SNN-1_TR_VALIDATION.df',
                './Results/final/SNN-2_TR_VALIDATION.df']

results_df = results_utils.mergeDataFrames(results_list, '.delete_this.df')  


results_df.loc[results_df.conf_id=='jawgqxcm'].mean(axis=0)
# Out:
# acc         0.878398
# prec        0.857841
# recall      0.808016
# f1-macro    0.827764
# dtype: float64

# %%
results_df.head()
# Out:
#     conf_id model_type architecture       acc      prec    recall  f1-macro
# 0  IMsHTOqQ          F        SNN-1  0.770629  0.765938  0.757870  0.760792
# 1  IMsHTOqQ          F        SNN-1  0.806993  0.804149  0.795749  0.798951
# 2  IMsHTOqQ          F        SNN-1  0.767507  0.761636  0.756389  0.758485
# 3  IMsHTOqQ          F        SNN-1  0.775910  0.783613  0.751956  0.758443
# 4  IMsHTOqQ          F        SNN-1  0.781513  0.775076  0.773956  0.774490
